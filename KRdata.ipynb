# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data1=pd.read_csv('/content/drive/MyDrive/valuechainproject/csv1.csv')

# %%
data1
# Out:
#           기간    HS코드                                                품목명  \
# 0         총계     NaN                                                NaN
# 1    2022-01  1001.0                                     밀과 메슬린(meslin)
# 2    2022-01  1005.0                                                옥수수
# 3    2022-01  1201.0                                    대두(부수었는지에 상관없다)
# 4    2022-01  1507.0      대두유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
# ..       ...     ...                                                ...
# 716  2024-12  7106.0  은(금이나 백금을 도금한 은을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 ...
# 717  2024-12  7108.0  금(백금을 도금한 금을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 ...
# 718  2024-12  7110.0            백금(가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
# 719  2024-12  7502.0                                           니켈의 괴(塊)
# 720  2024-12  7601.0                                         알루미늄의 괴(塊)
#
#          수출 중량     수출 금액         수입 중량      수입 금액       무역수지
# 0    4745154.0  18700760  1.213145e+09  569136316 -550435555
# 1          0.0         0  3.290137e+05     118122    -118122
# 2          0.3         3  1.019851e+06     337687    -337685
# 3          0.2         2  1.277796e+05      81692     -81690
# 4        218.1       444  3.523420e+04      48360     -47916
# ..         ...       ...           ...        ...        ...
# 716      236.1    165111  6.480000e+01      15519     149591
# 717        1.8     99514  1.800000e+00     137691     -38178
# 718        1.2     41256  3.700000e+00     141978    -100722
# 719      125.8      2097  2.555000e+03      42327     -40231
# 720    24577.5     68791  1.149414e+05     321492    -252701
#
# [721 rows x 8 columns]

# %%
data2=pd.read_csv('/content/drive/MyDrive/valuechainproject/csv2.csv')

# %%
data2
# Out:
#            기간    HS코드                                                품목명  \
# 0          총계     NaN                                                NaN
# 1     2022-01  2811.0                            그 밖의 무기산과 무기 비(非)금속 산화물
# 2     2022-01  3818.0  전자공업에 사용하기 위하여 도프처리된(doped) 화학원소(디스크ㆍ웨이퍼 모양이나 ...
# 3     2022-01  3901.0                에틸렌의 중합체[일차제품(primary form)으로 한정한다]
# 4     2022-01  4002.0  합성고무와 기름에서 제조한 팩티스(factice)[일차제품(primary form)...
# ...       ...     ...                                                ...
# 1429  2024-12  8113.0    서멧(cermet)과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
# 1430  2024-12  8501.0                               전동기와 발전기(발전세트는 제외한다)
# 1431  2024-12  8503.0    부분품(제8501호나 제8502호의 기계에 전용되거나 주로 사용되는 것으로 한정한다)
# 1432  2024-12  8507.0                축전지(격리판을 포함하며, 직사각형이나 정사각형인지에 상관없다)
# 1433  2024-12  9001.0  광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polari...
#
#            수출 중량      수출 금액       수입 중량     수입 금액      무역수지
# 0     90489941.3  143534434  37233365.2  81573027  61961407
# 1         4754.2      14284     21477.6     45644    -31360
# 2          197.6     102558      1040.4    208212   -105654
# 3       415139.5     666270     19776.1     41051    625219
# 4       170226.3     297405      9750.4     28008    269397
# ...          ...        ...         ...       ...       ...
# 1429        58.4       3259       195.2     11327     -8069
# 1430      8262.6     127575     12061.2    274344   -146769
# 1431      3233.0      41997      5027.0     49403     -7406
# 1432    102887.5     821442     25865.3    567765    253676
# 1433      8850.7     244587      2317.1    105133    139454
#
# [1434 rows x 8 columns]

# %%
data3=pd.read_csv('/content/drive/MyDrive/valuechainproject/csv3.csv')

# %%
data3
# Out:
#           기간      HS코드                                                품목명  \
# 0         총계       NaN                                                NaN
# 1    2022-01  870323.0                    실린더용량이 1,500시시 초과 3,000시시 이하인 것
# 2    2022-01  870324.0                             실린더용량이 3,000시시를 초과하는 것
# 3    2022-01  870350.0  그 밖의 차량[압축점화식 피스톤 내연기관(디젤이나 세미디젤)과 추진용 모터로서의 전...
# 4    2022-01  870360.0  그 밖의 차량(불꽃점화식 피스톤 내연기관과 추진용 모터로서의 전동기를 둘 다 갖춘 ...
# ..       ...       ...                                                ...
# 168  2024-12  870323.0                    실린더용량이 1,500시시 초과 3,000시시 이하인 것
# 169  2024-12  870324.0                             실린더용량이 3,000시시를 초과하는 것
# 170  2024-12  870350.0  그 밖의 차량[압축점화식 피스톤 내연기관(디젤이나 세미디젤)과 추진용 모터로서의 전...
# 171  2024-12  870360.0  그 밖의 차량(불꽃점화식 피스톤 내연기관과 추진용 모터로서의 전동기를 둘 다 갖춘 ...
# 172  2024-12  870370.0  그 밖의 차량[압축점화식 피스톤 내연기관(디젤이나 세미디젤)과 추진용 모터로서의 전...
#
#          수출 중량     수출 금액     수입 중량     수입 금액      무역수지
# 0    7025954.3  86853993  790254.5  18597775  68256218
# 1     124740.1   1337122   13320.7    268447   1068675
# 2      30624.6    493218    1349.5     69284    423934
# 3         15.2       115    1273.1     29935    -29820
# 4       7023.2    125277    1144.6     24451    100826
# ..         ...       ...       ...       ...       ...
# 168   178316.9   1845136   12843.7    206381   1638755
# 169    44100.2    758287     904.9     45801    712486
# 170       63.5      1361    3138.4     86564    -85203
# 171     7646.0    139357    2741.2     63419     75938
# 172        9.6       177       0.0         0       177
#
# [173 rows x 8 columns]

# %%
data4=pd.read_csv('/content/drive/MyDrive/valuechainproject/csv4.csv')

# %%
data4
# Out:
#          기간      HS코드                      품목명      수출 중량     수출 금액     수입 중량  \
# 0        총계       NaN                      NaN  1688353.4  32613238  282419.6
# 1   2022-01  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    33220.7    634598    1568.4
# 2   2022-02  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    34504.3    658165    6236.1
# 3   2022-03  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    32417.7    618966    3467.2
# 4   2022-04  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    29049.1    563491    3198.8
# 5   2022-05  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    32130.4    592321    8325.8
# 6   2022-06  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    27987.0    514299    3849.8
# 7   2022-07  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    40795.1    725211    5769.0
# 8   2022-08  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    30703.1    562606   17096.0
# 9   2022-09  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    36489.3    660648   12448.9
# 10  2022-10  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    40542.0    731799    8508.6
# 11  2022-11  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    43815.4    809028   11343.9
# 12  2022-12  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    58538.4   1104620    4038.0
# 13  2023-01  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    53787.8   1057571    3577.9
# 14  2023-02  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    61664.1   1206849    8321.6
# 15  2023-03  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    68910.9   1342360    4485.7
# 16  2023-04  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    58311.0   1147933    6743.4
# 17  2023-05  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    58523.6   1175970    5772.0
# 18  2023-06  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    65513.8   1311979   12402.2
# 19  2023-07  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    57850.0   1147051    4032.3
# 20  2023-08  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    51794.1   1052488   13473.6
# 21  2023-09  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    48957.2   1019646   14236.1
# 22  2023-10  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    51476.0   1019255   13235.9
# 23  2023-11  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    70877.2   1462074    7895.7
# 24  2023-12  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    67031.8   1391598    6432.8
# 25  2024-01  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    63104.0   1289747    2716.7
# 26  2024-02  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    49548.2    975119   14841.6
# 27  2024-03  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    56569.6   1115375   10759.1
# 28  2024-04  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    50745.6    971227   10073.4
# 29  2024-05  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    47693.8    919177   12231.6
# 30  2024-06  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    36867.5    697740    3606.8
# 31  2024-07  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    37727.6    731940   13041.3
# 32  2024-08  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    25663.7    488360    7715.1
# 33  2024-09  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    43817.5    816526    3500.1
# 34  2024-10  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    38992.4    705899    7581.4
# 35  2024-11  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    41577.9    707710    3428.1
# 36  2024-12  870380.0  그 밖의 차량(추진용 전동기만을 갖춘 것)    41155.4    683894    6464.8
#
#       수입 금액      무역수지
# 0   6127956  26485281
# 1     37013    597585
# 2    168911    489254
# 3     67005    551962
# 4     64429    499061
# 5    217708    374612
# 6     88082    426217
# 7     96127    629084
# 8    461498    101109
# 9    218917    441731
# 10   156886    574912
# 11   272515    536513
# 12    92259   1012361
# 13    90045    967525
# 14   218238    988611
# 15   108016   1234344
# 16   155287    992646
# 17   166870   1009100
# 18   286304   1025675
# 19   109754   1037297
# 20   258542    793946
# 21   295346    724300
# 22   256396    762859
# 23   187404   1274670
# 24   159592   1232006
# 25    57995   1231752
# 26   276832    698286
# 27   210069    905306
# 28   199702    771525
# 29   232492    686685
# 30    74101    623639
# 31   236452    495488
# 32   150327    338033
# 33    79570    736956
# 34   153879    552021
# 35    81713    625998
# 36   141682    542212

# %%
data5=pd.read_csv('/content/drive/MyDrive/valuechainproject/csv5.csv')

# %%
data5
# Out:
#            기간    HS코드                                                품목명  \
# 0          총계     NaN                                                NaN
# 1     2022-01  2106.0                                  따로 분류되지 않은 조제 식료품
# 2     2022-01  3004.0  의약품[혼합한 것인지에 상관없으며 치료용이나 예방용의 것으로서 일정한 투여량으로 한...
# 3     2022-01  6101.0  남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cap...
# 4     2022-01  6111.0              유아용 의류와 그 부속품(메리야스 편물이나 뜨개질 편물로 한정한다)
# ...       ...     ...                                                ...
# 1180  2024-12  9018.0  내과용ㆍ외과용ㆍ치과용ㆍ수의과용 기기[신티그래픽(scintigraphic)식 진단기기...
# 1181  2024-12  9019.0  기계요법용 기기, 마사지용 기기, 심리학적 적성검사용 기기, 오존 흡입기ㆍ산소 흡입...
# 1182  2024-12  9020.0  그 밖의 호흡용 기기와 가스마스크(기계적인 부분품과 교환용 필터를 모두 갖추지 않은...
# 1183  2024-12  9021.0  정형외과용 기기(목발ㆍ외과용 벨트와 탈장대를 포함한다), 골절 치료용 부목과 그 밖...
# 1184  2024-12  9022.0  엑스선이나 알파선ㆍ베타선ㆍ감마선ㆍ그 밖의 전리선을 사용하는 기기(내과용ㆍ외과용ㆍ치과...
#
#           수출 중량      수출 금액      수입 중량      수입 금액      무역수지
# 0     7628584.8  128567878  6007330.2  146567707 -17999829
# 1       14619.2      54494    14162.6     193086   -138592
# 2        1146.8      63657     5776.3     436509   -372852
# 3          68.3       1296       68.2       2823     -1527
# 4           8.8        374      142.3       4540     -4166
# ...         ...        ...        ...        ...       ...
# 1180     2298.6     246488     3112.8     248922     -2434
# 1181      128.8       7249     3535.6      43907    -36658
# 1182       73.6       1904       42.9       2766      -862
# 1183      200.6     110919      233.9      69951     40968
# 1184      821.5      82209      461.2      87525     -5316
#
# [1185 rows x 8 columns]

# %%
data5.sort_values(by=['HS코드','기간'],ascending=True)
# Out:
#            기간    HS코드                                                품목명  \
# 1     2022-01  2106.0                                  따로 분류되지 않은 조제 식료품
# 33    2022-02  2106.0                                  따로 분류되지 않은 조제 식료품
# 64    2022-03  2106.0                                  따로 분류되지 않은 조제 식료품
# 97    2022-04  2106.0                                  따로 분류되지 않은 조제 식료품
# 130   2022-05  2106.0                                  따로 분류되지 않은 조제 식료품
# ...       ...     ...                                                ...
# 1085  2024-09  9022.0  엑스선이나 알파선ㆍ베타선ㆍ감마선ㆍ그 밖의 전리선을 사용하는 기기(내과용ㆍ외과용ㆍ치과...
# 1117  2024-10  9022.0  엑스선이나 알파선ㆍ베타선ㆍ감마선ㆍ그 밖의 전리선을 사용하는 기기(내과용ㆍ외과용ㆍ치과...
# 1150  2024-11  9022.0  엑스선이나 알파선ㆍ베타선ㆍ감마선ㆍ그 밖의 전리선을 사용하는 기기(내과용ㆍ외과용ㆍ치과...
# 1184  2024-12  9022.0  엑스선이나 알파선ㆍ베타선ㆍ감마선ㆍ그 밖의 전리선을 사용하는 기기(내과용ㆍ외과용ㆍ치과...
# 0          총계     NaN                                                NaN
#
#           수출 중량      수출 금액      수입 중량      수입 금액      무역수지
# 1       14619.2      54494    14162.6     193086   -138592
# 33      15122.0      58032    13450.0     181457   -123425
# 64      17610.2      70118    14905.7     219029   -148911
# 97      16468.4      64693    13932.3     208187   -143494
# 130     16120.1      63690    15384.9     225599   -161909
# ...         ...        ...        ...        ...       ...
# 1085      652.2      78048      402.8      79154     -1106
# 1117      673.5      70585      326.9      60281     10304
# 1150      739.9      72299      257.5      48594     23705
# 1184      821.5      82209      461.2      87525     -5316
# 0     7628584.8  128567878  6007330.2  146567707 -17999829
#
# [1185 rows x 8 columns]

# %%
import torch

# %%
X = data5.iloc[:,[0,1,3,5]]

# %%
X
# Out:
#            기간    HS코드      수출 중량      수입 중량
# 0          총계     NaN  7628584.8  6007330.2
# 1     2022-01  2106.0    14619.2    14162.6
# 2     2022-01  3004.0     1146.8     5776.3
# 3     2022-01  6101.0       68.3       68.2
# 4     2022-01  6111.0        8.8      142.3
# ...       ...     ...        ...        ...
# 1180  2024-12  9018.0     2298.6     3112.8
# 1181  2024-12  9019.0      128.8     3535.6
# 1182  2024-12  9020.0       73.6       42.9
# 1183  2024-12  9021.0      200.6      233.9
# 1184  2024-12  9022.0      821.5      461.2
#
# [1185 rows x 4 columns]

# %%
Y=data5.sort_values(by=['HS코드','기간'],ascending=True).iloc[0:3,[0,1,4,6]]

# %%
Y
# Out:
#          기간    HS코드  수출 금액   수입 금액
# 1   2022-01  2106.0  54494  193086
# 33  2022-02  2106.0  58032  181457
# 64  2022-03  2106.0  70118  219029

# %%
concated=pd.concat([data1,data2,data3,data4,data5])

# %%
concated
# Out:
#            기간    HS코드                                                품목명  \
# 0          총계     NaN                                                NaN
# 1     2022-01  1001.0                                     밀과 메슬린(meslin)
# 2     2022-01  1005.0                                                옥수수
# 3     2022-01  1201.0                                    대두(부수었는지에 상관없다)
# 4     2022-01  1507.0      대두유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
# ...       ...     ...                                                ...
# 1180  2024-12  9018.0  내과용ㆍ외과용ㆍ치과용ㆍ수의과용 기기[신티그래픽(scintigraphic)식 진단기기...
# 1181  2024-12  9019.0  기계요법용 기기, 마사지용 기기, 심리학적 적성검사용 기기, 오존 흡입기ㆍ산소 흡입...
# 1182  2024-12  9020.0  그 밖의 호흡용 기기와 가스마스크(기계적인 부분품과 교환용 필터를 모두 갖추지 않은...
# 1183  2024-12  9021.0  정형외과용 기기(목발ㆍ외과용 벨트와 탈장대를 포함한다), 골절 치료용 부목과 그 밖...
# 1184  2024-12  9022.0  엑스선이나 알파선ㆍ베타선ㆍ감마선ㆍ그 밖의 전리선을 사용하는 기기(내과용ㆍ외과용ㆍ치과...
#
#           수출 중량     수출 금액         수입 중량      수입 금액       무역수지
# 0     4745154.0  18700760  1.213145e+09  569136316 -550435555
# 1           0.0         0  3.290137e+05     118122    -118122
# 2           0.3         3  1.019851e+06     337687    -337685
# 3           0.2         2  1.277796e+05      81692     -81690
# 4         218.1       444  3.523420e+04      48360     -47916
# ...         ...       ...           ...        ...        ...
# 1180     2298.6    246488  3.112800e+03     248922      -2434
# 1181      128.8      7249  3.535600e+03      43907     -36658
# 1182       73.6      1904  4.290000e+01       2766       -862
# 1183      200.6    110919  2.339000e+02      69951      40968
# 1184      821.5     82209  4.612000e+02      87525      -5316
#
# [3550 rows x 8 columns]

# %%
raw=concated.sort_values(by=['HS코드','기간'],ascending=True).iloc[0:concated.shape[0]-5,[0,2,4,6]]

# %%
raw
# Out:
#          기간                      품목명   수출 금액   수입 금액
# 1   2022-01           밀과 메슬린(meslin)       0  118122
# 21  2022-02           밀과 메슬린(meslin)       0  112580
# 41  2022-03           밀과 메슬린(meslin)       0  172448
# 61  2022-04           밀과 메슬린(meslin)       0  169623
# 81  2022-05           밀과 메슬린(meslin)       0  189315
# ..      ...                      ...     ...     ...
# 32  2024-08  그 밖의 차량(추진용 전동기만을 갖춘 것)  488360  150327
# 33  2024-09  그 밖의 차량(추진용 전동기만을 갖춘 것)  816526   79570
# 34  2024-10  그 밖의 차량(추진용 전동기만을 갖춘 것)  705899  153879
# 35  2024-11  그 밖의 차량(추진용 전동기만을 갖춘 것)  707710   81713
# 36  2024-12  그 밖의 차량(추진용 전동기만을 갖춘 것)  683894  141682
#
# [3545 rows x 4 columns]

# %%
raw['기간'] = pd.to_datetime(raw['기간']).dt.to_period('Q')

# %%
raw['계']=raw['수출 금액']+raw['수입 금액']

# %%
quarterly_avg_trade = raw.groupby(['품목명', '기간'])['계'].mean().reset_index()

# %%
quarterly_avg_trade
# Out:
#                                                     품목명      기간            계
# 0     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2022Q1  1327.000000
# 1     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2022Q2  1345.000000
# 2     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2022Q3  1059.000000
# 3     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2022Q4   614.000000
# 4     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2023Q1   691.000000
# ...                                                 ...     ...          ...
# 1173  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2023Q4  4156.333333
# 1174  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2024Q1  3308.666667
# 1175  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2024Q2  3470.666667
# 1176  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2024Q3  3671.000000
# 1177  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2024Q4  4160.333333
#
# [1178 rows x 3 columns]

# %%
quarter_counts = quarterly_avg_trade.groupby('품목명')['기간'].nunique()

# 12개 분기 모두 존재하는 품목만 필터링
valid_items = quarter_counts[quarter_counts == 12].index

# 해당 품목만 포함된 데이터프레임 생성
filtered_df = quarterly_avg_trade[quarterly_avg_trade['품목명'].isin(valid_items)]

# 결과 확인
print(filtered_df.shape)
# Out:
# (1128, 3)

# %%
filtered_df
# Out:
#                                                     품목명      기간            계
# 0     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2022Q1  1327.000000
# 1     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2022Q2  1345.000000
# 2     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2022Q3  1059.000000
# 3     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2022Q4   614.000000
# 4     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2023Q1   691.000000
# ...                                                 ...     ...          ...
# 1173  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2023Q4  4156.333333
# 1174  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2024Q1  3308.666667
# 1175  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2024Q2  3470.666667
# 1176  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2024Q3  3671.000000
# 1177  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2024Q4  4160.333333
#
# [1128 rows x 3 columns]

# %%
filtered_df['분기별 상승률'] = (
    filtered_df.groupby('품목명')['계']
    .transform(lambda x: x.pct_change())
)
# Out:
# <ipython-input-29-dacd9a649870>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['분기별 상승률'] = (

# %%
filtered_df
# Out:
#                                                     품목명      기간            계  \
# 0     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2022Q1  1327.000000
# 1     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2022Q2  1345.000000
# 2     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2022Q3  1059.000000
# 3     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2022Q4   614.000000
# 4     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...  2023Q1   691.000000
# ...                                                 ...     ...          ...
# 1173  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2023Q4  4156.333333
# 1174  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2024Q1  3308.666667
# 1175  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2024Q2  3470.666667
# 1176  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2024Q3  3671.000000
# 1177  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...  2024Q4  4160.333333
#
#        분기별 상승률
# 0          NaN
# 1     0.013564
# 2    -0.212639
# 3    -0.420208
# 4     0.125407
# ...        ...
# 1173  0.118597
# 1174 -0.203946
# 1175  0.048962
# 1176  0.057722
# 1177  0.133297
#
# [1128 rows x 4 columns]

# %%
pivot_df = filtered_df.pivot(index='품목명', columns='기간', values='분기별 상승률')

# %%
pivot_df
# Out:
# 기간                                                  2022Q1    2022Q2  \
# 품목명
# 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 ...     NaN  0.013564
# 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric...     NaN -0.113604
# 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polariz...     NaN -0.147109
# 구리광과 그 정광(精鑛)                                          NaN  0.045692
# 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며,...     NaN -0.007958
# ...                                                    ...       ...
# 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다)     NaN -0.071699
# 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)                   NaN  0.121131
# 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이,...     NaN -0.104603
# 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine...     NaN  0.096905
# 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, ...     NaN  0.400359
#
# 기간                                                    2022Q3    2022Q4  \
# 품목명
# 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 ... -0.212639 -0.420208
# 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric...  0.083072  0.266692
# 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polariz... -0.093354 -0.160175
# 구리광과 그 정광(精鑛)                                      -0.027375 -0.223102
# 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며,... -0.053165 -0.194101
# ...                                                      ...       ...
# 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다) -0.059614 -0.131828
# 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)               -0.113998  0.066230
# 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이,... -0.065880  0.143941
# 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine... -0.055703 -0.052278
# 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, ... -0.254953  0.352992
#
# 기간                                                    2023Q1    2023Q2  \
# 품목명
# 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 ...  0.125407  0.281235
# 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric... -0.315265  0.227999
# 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polariz... -0.112045 -0.055232
# 구리광과 그 정광(精鑛)                                      -0.017022  0.257276
# 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며,...  0.113617  0.116846
# ...                                                      ...       ...
# 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다)  0.037802 -0.015338
# 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)               -0.107150  0.064200
# 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이,...  0.340395 -0.119732
# 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine...  0.076486 -0.091778
# 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, ... -0.328477 -0.002152
#
# 기간                                                    2023Q3    2023Q4  \
# 품목명
# 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 ... -0.236446  0.071499
# 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric... -0.128223  0.650700
# 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polariz...  0.134056 -0.073754
# 구리광과 그 정광(精鑛)                                      -0.083480 -0.079345
# 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며,... -0.127848 -0.028466
# ...                                                      ...       ...
# 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다) -0.093337 -0.037974
# 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)               -0.200059  0.213081
# 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이,... -0.039101 -0.056504
# 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine... -0.066442 -0.023182
# 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, ... -0.038306  0.118597
#
# 기간                                                    2024Q1    2024Q2  \
# 품목명
# 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 ... -0.193281  0.076440
# 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric... -0.154638 -0.123737
# 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polariz...  0.048444  0.018829
# 구리광과 그 정광(精鑛)                                      -0.146434  0.167875
# 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며,...  0.069151 -0.017058
# ...                                                      ...       ...
# 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다)  0.013694  0.078545
# 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)               -0.085614  0.114352
# 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이,...  0.094713 -0.104081
# 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine...  0.036938 -0.042568
# 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, ... -0.203946  0.048962
#
# 기간                                                    2024Q3    2024Q4
# 품목명
# 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 ... -0.002650  0.133900
# 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric... -0.170613 -0.243435
# 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polariz... -0.004592 -0.009909
# 구리광과 그 정광(精鑛)                                      -0.098861 -0.341158
# 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며,... -0.102822  0.151724
# ...                                                      ...       ...
# 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다) -0.096675  0.012362
# 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)               -0.170423  0.158005
# 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이,... -0.007723  0.034858
# 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine...  0.026788 -0.016125
# 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, ...  0.057722  0.133297
#
# [94 rows x 12 columns]

# %%
pivot_df.iloc[:,1:]
# Out:
# 기간                                                    2022Q2    2022Q3  \
# 품목명
# 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 ...  0.013564 -0.212639
# 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric... -0.113604  0.083072
# 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polariz... -0.147109 -0.093354
# 구리광과 그 정광(精鑛)                                       0.045692 -0.027375
# 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며,... -0.007958 -0.053165
# ...                                                      ...       ...
# 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다) -0.071699 -0.059614
# 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)                0.121131 -0.113998
# 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이,... -0.104603 -0.065880
# 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine...  0.096905 -0.055703
# 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, ...  0.400359 -0.254953
#
# 기간                                                    2022Q4    2023Q1  \
# 품목명
# 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 ... -0.420208  0.125407
# 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric...  0.266692 -0.315265
# 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polariz... -0.160175 -0.112045
# 구리광과 그 정광(精鑛)                                      -0.223102 -0.017022
# 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며,... -0.194101  0.113617
# ...                                                      ...       ...
# 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다) -0.131828  0.037802
# 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)                0.066230 -0.107150
# 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이,...  0.143941  0.340395
# 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine... -0.052278  0.076486
# 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, ...  0.352992 -0.328477
#
# 기간                                                    2023Q2    2023Q3  \
# 품목명
# 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 ...  0.281235 -0.236446
# 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric...  0.227999 -0.128223
# 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polariz... -0.055232  0.134056
# 구리광과 그 정광(精鑛)                                       0.257276 -0.083480
# 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며,...  0.116846 -0.127848
# ...                                                      ...       ...
# 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다) -0.015338 -0.093337
# 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)                0.064200 -0.200059
# 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이,... -0.119732 -0.039101
# 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine... -0.091778 -0.066442
# 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, ... -0.002152 -0.038306
#
# 기간                                                    2023Q4    2024Q1  \
# 품목명
# 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 ...  0.071499 -0.193281
# 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric...  0.650700 -0.154638
# 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polariz... -0.073754  0.048444
# 구리광과 그 정광(精鑛)                                      -0.079345 -0.146434
# 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며,... -0.028466  0.069151
# ...                                                      ...       ...
# 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다) -0.037974  0.013694
# 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)                0.213081 -0.085614
# 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이,... -0.056504  0.094713
# 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine... -0.023182  0.036938
# 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, ...  0.118597 -0.203946
#
# 기간                                                    2024Q2    2024Q3  \
# 품목명
# 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 ...  0.076440 -0.002650
# 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric... -0.123737 -0.170613
# 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polariz...  0.018829 -0.004592
# 구리광과 그 정광(精鑛)                                       0.167875 -0.098861
# 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며,... -0.017058 -0.102822
# ...                                                      ...       ...
# 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다)  0.078545 -0.096675
# 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)                0.114352 -0.170423
# 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이,... -0.104081 -0.007723
# 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine... -0.042568  0.026788
# 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, ...  0.048962  0.057722
#
# 기간                                                    2024Q4
# 품목명
# 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 ...  0.133900
# 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric... -0.243435
# 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polariz... -0.009909
# 구리광과 그 정광(精鑛)                                      -0.341158
# 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며,...  0.151724
# ...                                                      ...
# 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다)  0.012362
# 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)                0.158005
# 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이,...  0.034858
# 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine... -0.016125
# 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, ...  0.133297
#
# [94 rows x 11 columns]

# %%
pivot_df = pivot_df.reset_index()

# %%
pivot_df
# Out:
# 기간                                                품목명  2022Q1    2022Q2  \
# 0   겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...     NaN  0.013564
# 1   공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectri...     NaN -0.113604
# 2   광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polari...     NaN -0.147109
# 3                                       구리광과 그 정광(精鑛)     NaN  0.045692
# 4   그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며...     NaN -0.007958
# ..                                                ...     ...       ...
# 89  합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포...     NaN -0.071699
# 90               합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)     NaN  0.121131
# 91  화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이...     NaN -0.104603
# 92  황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassin...     NaN  0.096905
# 93  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...     NaN  0.400359
#
# 기간    2022Q3    2022Q4    2023Q1    2023Q2    2023Q3    2023Q4    2024Q1  \
# 0  -0.212639 -0.420208  0.125407  0.281235 -0.236446  0.071499 -0.193281
# 1   0.083072  0.266692 -0.315265  0.227999 -0.128223  0.650700 -0.154638
# 2  -0.093354 -0.160175 -0.112045 -0.055232  0.134056 -0.073754  0.048444
# 3  -0.027375 -0.223102 -0.017022  0.257276 -0.083480 -0.079345 -0.146434
# 4  -0.053165 -0.194101  0.113617  0.116846 -0.127848 -0.028466  0.069151
# ..       ...       ...       ...       ...       ...       ...       ...
# 89 -0.059614 -0.131828  0.037802 -0.015338 -0.093337 -0.037974  0.013694
# 90 -0.113998  0.066230 -0.107150  0.064200 -0.200059  0.213081 -0.085614
# 91 -0.065880  0.143941  0.340395 -0.119732 -0.039101 -0.056504  0.094713
# 92 -0.055703 -0.052278  0.076486 -0.091778 -0.066442 -0.023182  0.036938
# 93 -0.254953  0.352992 -0.328477 -0.002152 -0.038306  0.118597 -0.203946
#
# 기간    2024Q2    2024Q3    2024Q4
# 0   0.076440 -0.002650  0.133900
# 1  -0.123737 -0.170613 -0.243435
# 2   0.018829 -0.004592 -0.009909
# 3   0.167875 -0.098861 -0.341158
# 4  -0.017058 -0.102822  0.151724
# ..       ...       ...       ...
# 89  0.078545 -0.096675  0.012362
# 90  0.114352 -0.170423  0.158005
# 91 -0.104081 -0.007723  0.034858
# 92 -0.042568  0.026788 -0.016125
# 93  0.048962  0.057722  0.133297
#
# [94 rows x 13 columns]

# %%
pivot_df.iloc[:,0]
# Out:
# 0     겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...
# 1     공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectri...
# 2     광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polari...
# 3                                         구리광과 그 정광(精鑛)
# 4     그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며...
#                             ...
# 89    합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포...
# 90                 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)
# 91    화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이...
# 92    황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassin...
# 93    휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...
# Name: 품목명, Length: 94, dtype: object

# %%
pivot_df.iloc[:,2:]
# Out:
# 기간    2022Q2    2022Q3    2022Q4    2023Q1    2023Q2    2023Q3    2023Q4  \
# 0   0.013564 -0.212639 -0.420208  0.125407  0.281235 -0.236446  0.071499
# 1  -0.113604  0.083072  0.266692 -0.315265  0.227999 -0.128223  0.650700
# 2  -0.147109 -0.093354 -0.160175 -0.112045 -0.055232  0.134056 -0.073754
# 3   0.045692 -0.027375 -0.223102 -0.017022  0.257276 -0.083480 -0.079345
# 4  -0.007958 -0.053165 -0.194101  0.113617  0.116846 -0.127848 -0.028466
# ..       ...       ...       ...       ...       ...       ...       ...
# 89 -0.071699 -0.059614 -0.131828  0.037802 -0.015338 -0.093337 -0.037974
# 90  0.121131 -0.113998  0.066230 -0.107150  0.064200 -0.200059  0.213081
# 91 -0.104603 -0.065880  0.143941  0.340395 -0.119732 -0.039101 -0.056504
# 92  0.096905 -0.055703 -0.052278  0.076486 -0.091778 -0.066442 -0.023182
# 93  0.400359 -0.254953  0.352992 -0.328477 -0.002152 -0.038306  0.118597
#
# 기간    2024Q1    2024Q2    2024Q3    2024Q4
# 0  -0.193281  0.076440 -0.002650  0.133900
# 1  -0.154638 -0.123737 -0.170613 -0.243435
# 2   0.048444  0.018829 -0.004592 -0.009909
# 3  -0.146434  0.167875 -0.098861 -0.341158
# 4   0.069151 -0.017058 -0.102822  0.151724
# ..       ...       ...       ...       ...
# 89  0.013694  0.078545 -0.096675  0.012362
# 90 -0.085614  0.114352 -0.170423  0.158005
# 91  0.094713 -0.104081 -0.007723  0.034858
# 92  0.036938 -0.042568  0.026788 -0.016125
# 93 -0.203946  0.048962  0.057722  0.133297
#
# [94 rows x 11 columns]

# %%
import numpy as np

# '2022Q1'을 제외한 분기 컬럼만 선택
cols_to_check = pivot_df.iloc[:,2:].columns

# inf를 NaN으로 먼저 바꾸고, '2022Q1' 제외한 나머지에 NaN이 있는 행 제거
clean_pivot_df = pivot_df.replace([np.inf, -np.inf], np.nan)
clean_pivot_df = clean_pivot_df.dropna(subset=cols_to_check)

# 결과 확인
print(clean_pivot_df.shape)
clean_pivot_df.head()
pivot_df=clean_pivot_df
# Out:
# (93, 13)

# %%
pivot_df.iloc[:,2:]
# Out:
# 기간    2022Q2    2022Q3    2022Q4    2023Q1    2023Q2    2023Q3    2023Q4  \
# 0   0.013564 -0.212639 -0.420208  0.125407  0.281235 -0.236446  0.071499
# 1  -0.113604  0.083072  0.266692 -0.315265  0.227999 -0.128223  0.650700
# 2  -0.147109 -0.093354 -0.160175 -0.112045 -0.055232  0.134056 -0.073754
# 3   0.045692 -0.027375 -0.223102 -0.017022  0.257276 -0.083480 -0.079345
# 4  -0.007958 -0.053165 -0.194101  0.113617  0.116846 -0.127848 -0.028466
# ..       ...       ...       ...       ...       ...       ...       ...
# 89 -0.071699 -0.059614 -0.131828  0.037802 -0.015338 -0.093337 -0.037974
# 90  0.121131 -0.113998  0.066230 -0.107150  0.064200 -0.200059  0.213081
# 91 -0.104603 -0.065880  0.143941  0.340395 -0.119732 -0.039101 -0.056504
# 92  0.096905 -0.055703 -0.052278  0.076486 -0.091778 -0.066442 -0.023182
# 93  0.400359 -0.254953  0.352992 -0.328477 -0.002152 -0.038306  0.118597
#
# 기간    2024Q1    2024Q2    2024Q3    2024Q4
# 0  -0.193281  0.076440 -0.002650  0.133900
# 1  -0.154638 -0.123737 -0.170613 -0.243435
# 2   0.048444  0.018829 -0.004592 -0.009909
# 3  -0.146434  0.167875 -0.098861 -0.341158
# 4   0.069151 -0.017058 -0.102822  0.151724
# ..       ...       ...       ...       ...
# 89  0.013694  0.078545 -0.096675  0.012362
# 90 -0.085614  0.114352 -0.170423  0.158005
# 91  0.094713 -0.104081 -0.007723  0.034858
# 92  0.036938 -0.042568  0.026788 -0.016125
# 93 -0.203946  0.048962  0.057722  0.133297
#
# [93 rows x 11 columns]

# %%
mask = (pivot_df[cols_to_check].abs() > 5).any(axis=1)

# %%
mask
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 89    False
# 90    False
# 91    False
# 92    False
# 93    False
# Length: 93, dtype: bool

# %%
pivot_df=pivot_df[~mask]

# %%
pivot_df
# Out:
# 기간                                                품목명  2022Q1    2022Q2  \
# 0   겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...     NaN  0.013564
# 1   공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectri...     NaN -0.113604
# 2   광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polari...     NaN -0.147109
# 3                                       구리광과 그 정광(精鑛)     NaN  0.045692
# 4   그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며...     NaN -0.007958
# ..                                                ...     ...       ...
# 89  합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포...     NaN -0.071699
# 90               합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)     NaN  0.121131
# 91  화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이...     NaN -0.104603
# 92  황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassin...     NaN  0.096905
# 93  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...     NaN  0.400359
#
# 기간    2022Q3    2022Q4    2023Q1    2023Q2    2023Q3    2023Q4    2024Q1  \
# 0  -0.212639 -0.420208  0.125407  0.281235 -0.236446  0.071499 -0.193281
# 1   0.083072  0.266692 -0.315265  0.227999 -0.128223  0.650700 -0.154638
# 2  -0.093354 -0.160175 -0.112045 -0.055232  0.134056 -0.073754  0.048444
# 3  -0.027375 -0.223102 -0.017022  0.257276 -0.083480 -0.079345 -0.146434
# 4  -0.053165 -0.194101  0.113617  0.116846 -0.127848 -0.028466  0.069151
# ..       ...       ...       ...       ...       ...       ...       ...
# 89 -0.059614 -0.131828  0.037802 -0.015338 -0.093337 -0.037974  0.013694
# 90 -0.113998  0.066230 -0.107150  0.064200 -0.200059  0.213081 -0.085614
# 91 -0.065880  0.143941  0.340395 -0.119732 -0.039101 -0.056504  0.094713
# 92 -0.055703 -0.052278  0.076486 -0.091778 -0.066442 -0.023182  0.036938
# 93 -0.254953  0.352992 -0.328477 -0.002152 -0.038306  0.118597 -0.203946
#
# 기간    2024Q2    2024Q3    2024Q4
# 0   0.076440 -0.002650  0.133900
# 1  -0.123737 -0.170613 -0.243435
# 2   0.018829 -0.004592 -0.009909
# 3   0.167875 -0.098861 -0.341158
# 4  -0.017058 -0.102822  0.151724
# ..       ...       ...       ...
# 89  0.078545 -0.096675  0.012362
# 90  0.114352 -0.170423  0.158005
# 91 -0.104081 -0.007723  0.034858
# 92 -0.042568  0.026788 -0.016125
# 93  0.048962  0.057722  0.133297
#
# [92 rows x 13 columns]

# %%
from sklearn.preprocessing import StandardScaler

# 수치형 변화율 열만 선택 (첫 번째 열은 품목명이라 제외)
value_columns = pivot_df.columns[2:]

# 스케일러로 z-score 정규화
scaler = StandardScaler()
pivot_df[value_columns] = scaler.fit_transform(pivot_df[value_columns])

# 결과 확인
pivot_df.head()
# Out:
# <ipython-input-46-702b3352ff3e>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pivot_df[value_columns] = scaler.fit_transform(pivot_df[value_columns])
# 기간                                                품목명  2022Q1    2022Q2  \
# 0   겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...     NaN -0.153059
# 1   공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectri...     NaN -0.661671
# 2   광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polari...     NaN -0.795678
# 3                                       구리광과 그 정광(精鑛)     NaN -0.024566
# 4   그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며...     NaN -0.239138
#
# 기간    2022Q3    2022Q4    2023Q1    2023Q2    2023Q3    2023Q4    2024Q1  \
# 0  -0.382504 -1.500158  0.415215  0.900296 -0.549433  0.031947 -0.725997
# 1   0.055902  0.960124 -1.126956  0.699102 -0.270982  1.865159 -0.571444
# 2  -0.205658 -0.568794 -0.415771 -0.371314  0.403851 -0.427790  0.240785
# 3  -0.107841 -0.794180 -0.083228  0.809748 -0.155859 -0.445485 -0.538631
# 4  -0.146075 -0.690307  0.373954  0.279018 -0.270016 -0.284451  0.323604
#
# 기간    2024Q2    2024Q3    2024Q4
# 0   0.005210 -0.118839  0.559860
# 1  -0.824967 -0.458321 -1.650879
# 2  -0.233715 -0.122764 -0.282688
# 3   0.384408 -0.313298 -2.223415
# 4  -0.382545 -0.321304  0.664284

# %%
pivot_df = pivot_df.reset_index()

# %%
pivot_df
# Out:
# 기간  index                                                품목명  2022Q1  \
# 0       0  겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...     NaN
# 1       1  공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectri...     NaN
# 2       2  광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polari...     NaN
# 3       3                                      구리광과 그 정광(精鑛)     NaN
# 4       4  그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며...     NaN
# ..    ...                                                ...     ...
# 87     89  합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포...     NaN
# 88     90               합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)     NaN
# 89     91  화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이...     NaN
# 90     92  황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassin...     NaN
# 91     93  휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며,...     NaN
#
# 기간    2022Q2    2022Q3    2022Q4    2023Q1    2023Q2    2023Q3    2023Q4  \
# 0  -0.153059 -0.382504 -1.500158  0.415215  0.900296 -0.549433  0.031947
# 1  -0.661671  0.055902  0.960124 -1.126956  0.699102 -0.270982  1.865159
# 2  -0.795678 -0.205658 -0.568794 -0.415771 -0.371314  0.403851 -0.427790
# 3  -0.024566 -0.107841 -0.794180 -0.083228  0.809748 -0.155859 -0.445485
# 4  -0.239138 -0.146075 -0.690307  0.373954  0.279018 -0.270016 -0.284451
# ..       ...       ...       ...       ...       ...       ...       ...
# 87 -0.494074 -0.155637 -0.467264  0.108634 -0.220546 -0.181221 -0.314544
# 88  0.277155 -0.236264  0.242125 -0.398641  0.080053 -0.455810  0.480065
# 89 -0.625674 -0.164927  0.520465  1.167586 -0.615082 -0.041675 -0.373191
# 90  0.180262 -0.149838 -0.182338  0.244012 -0.509435 -0.112021 -0.267727
# 91  1.393936 -0.445236  1.269226 -1.173194 -0.170711 -0.039627  0.181015
#
# 기간    2024Q1    2024Q2    2024Q3    2024Q4
# 0  -0.725997  0.005210 -0.118839  0.559860
# 1  -0.571444 -0.824967 -0.458321 -1.650879
# 2   0.240785 -0.233715 -0.122764 -0.282688
# 3  -0.538631  0.384408 -0.313298 -2.223415
# 4   0.323604 -0.382545 -0.321304  0.664284
# ..       ...       ...       ...       ...
# 87  0.101805  0.013938 -0.308879 -0.152207
# 88 -0.295380  0.162437 -0.457937  0.701083
# 89  0.425839 -0.743449 -0.129093 -0.020407
# 90  0.194767 -0.488343 -0.059341 -0.319107
# 91 -0.768650 -0.108747  0.003181  0.556326
#
# [92 rows x 14 columns]

# %%
feature_tensor = torch.tensor(pivot_df.iloc[:,3:].values, dtype=torch.float64)

# %%
feature_tensor
# Out:
# tensor([[-0.1531, -0.3825, -1.5002,  ...,  0.0052, -0.1188,  0.5599],
#         [-0.6617,  0.0559,  0.9601,  ..., -0.8250, -0.4583, -1.6509],
#         [-0.7957, -0.2057, -0.5688,  ..., -0.2337, -0.1228, -0.2827],
#         ...,
#         [-0.6257, -0.1649,  0.5205,  ..., -0.7434, -0.1291, -0.0204],
#         [ 0.1803, -0.1498, -0.1823,  ..., -0.4883, -0.0593, -0.3191],
#         [ 1.3939, -0.4452,  1.2692,  ..., -0.1087,  0.0032,  0.5563]],
#        dtype=torch.float64)

# %%
from sklearn.cluster import KMeans

# %%
import torch

print("Any NaN:", torch.isnan(feature_tensor).any().item())
print("Any Inf:", torch.isinf(feature_tensor).any().item())
print("Max:", feature_tensor.max().item())
print("Min:", feature_tensor.min().item())
# Out:
# Any NaN: False
# Any Inf: False
# Max: 7.044996506546491
# Min: -2.72407385284161

# %%
common_params = {
    "n_init": "auto",
    "random_state": 170,
}
y_pred1 = KMeans(n_clusters=10, **common_params).fit_predict(feature_tensor)

# %%
y_pred1.shape
# Out:
# (92,)

# %%
import pandas as pd

# 클러스터 결과 Series 생성
cluster_labels = pd.Series(y_pred1, name='클러스터')

# 품목명과 클러스터를 연결
result_df = pd.concat([pivot_df.iloc[:, 1], cluster_labels], axis=1)

# 클러스터별 품목 분포 확인
result_df.sort_values('클러스터').reset_index(drop=True)
# Out:
#                                                   품목명  클러스터
# 0   겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로...     0
# 1   광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polari...     0
# 2                             그 밖의 무기산과 무기 비(非)금속 산화물     0
# 3   그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며...     0
# 4                             그 밖의 차량(추진용 전동기만을 갖춘 것)     0
# ..                                                ...   ...
# 87                     인조필라멘트사(재봉사는 제외하며, 소매용으로 한정한다)     7
# 88          지르코늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]     8
# 89          안티모니와 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]     8
# 90         자주식(自走式) 철도용이나 궤도용 객차와 화차(제8604호의 것은 제외한다)     9
# 91  철강으로 만든 구조물(제9406호의 조립식 건축물은 제외한다)과 구조물의 부분품[예...     9
#
# [92 rows x 2 columns]

# %%
# 'pivot_df'의 첫 번째 열이 '품목명'이라고 가정
품목명_series = pivot_df.iloc[:, 1]

# 클러스터 결과를 붙이기
result_df = pd.DataFrame({
    '품목명': 품목명_series,
    '클러스터': y_pred1
})

# 클러스터별 품목 리스트 출력
for cluster_id, group in result_df.groupby('클러스터'):
    print(f"\n🔹 클러스터 {cluster_id} (총 {len(group)}개 품목)")
    for name in group['품목명']:
        print(f" - {name}")
# Out:
# 🔹 클러스터 0 (총 43개 품목)
#  - 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 한정하며, 표면을 도포하거나 침투시킨 것은 제외하고, 내면을 보강했는지에 상관없다]
#  - 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polarizing material)로 만든 판, 각종 재료로 만든 렌즈(콘택트렌즈를 포함한다)ㆍ프리즘ㆍ반사경과 그 밖의 광학소자로서 장착되지 않은 것(광학적으로 가공하지 않은 유리로 만든 광학소자는 제외한다)
#  - 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 이 류의 주 제3호의 것 이상의 가공을 하지 않은 것으로 한정한다]
#  - 그 밖의 무기산과 무기 비(非)금속 산화물
#  - 그 밖의 차량(추진용 전동기만을 갖춘 것)
#  - 그 밖의 호흡용 기기와 가스마스크(기계적인 부분품과 교환용 필터를 모두 갖추지 않은 보호용 마스크는 제외한다)
#  - 기계요법용 기기, 마사지용 기기, 심리학적 적성검사용 기기, 오존 흡입기ㆍ산소 흡입기ㆍ에어로졸 치료기ㆍ인공호흡기나 그 밖의 치료용 호흡기기
#  - 내과용ㆍ외과용ㆍ치과용ㆍ수의과용 기기[신티그래픽(scintigraphic)식 진단기기ㆍ그 밖의 전기식 의료기기와 시력 검사기기를 포함한다]
#  - 니켈의 괴(塊)
#  - 따로 분류되지 않은 조제 식료품
#  - 망간과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 면[카드(card)하지도 코움(comb)하지도 않은 것으로 한정한다]
#  - 물결 모양으로 하거나(corrugated)(평면지가 붙은 것인지에 상관없다) 주름지거나(creped) 구겨지거나(crinkled) 올록볼록하거나(embossed) 구멍을 뚫은(perforated) 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 제4803호의 것은 제외한다]
#  - 반도체 디바이스(예: 다이오드ㆍ트랜지스터ㆍ반도체 기반 트랜스듀서), 감광성 반도체 디바이스(광전지는 모듈에 조립되었거나 패널로 구성되었는지 여부와 관계없이 포함한다), 발광다이오드[(엘이디), 다른 발광다이오드와 결합되었는지 여부과 관계없이 포함한다], 장착된 압전기 결정소자
#  - 불꽃점화식이나 압축점화식 내연기관의 점화용ㆍ시동용 전기기기(예: 점화용 자석발전기ㆍ자석발전기ㆍ점화코일ㆍ점화플러그ㆍ예열플러그ㆍ시동전동기), 내연기관에 부속되는 발전기(예: 직류발전기ㆍ교류발전기)와 개폐기
#  - 석유가스와 그 밖의 가스 상태의 탄화수소
#  - 실험실용ㆍ화학용이나 그 밖의 공업용 도자제품, 농업용 도자제 통과 이와 유사한 용기, 물품의 수송용ㆍ포장용으로 사용하는 도자제의 항아리ㆍ단지와 이와 유사한 제품
#  - 알루미늄의 괴(塊)
#  - 엑스선이나 알파선ㆍ베타선ㆍ감마선ㆍ그 밖의 전리선을 사용하는 기기(내과용ㆍ외과용ㆍ치과용ㆍ수의과용인지에 상관없으며 방사선 사진용이나 방사선 치료용 기기ㆍ엑스선관과 그 밖의 엑스선 발생기ㆍ고압 발생기ㆍ조절반ㆍ스크린ㆍ검사용이나 치료용 테이블ㆍ의자와 이와 유사한 물품을 포함한다)
#  - 옥수수
#  - 원목[껍질ㆍ변재(邊材)를 벗긴 것인지 또는 거칠게 각을 뜬 것인지에 상관없다]
#  - 은(금이나 백금을 도금한 은을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#  - 재생ㆍ반(半)합성 필라멘트사[재봉사와 소매용은 제외하며, 67데시텍스 미만인 재생ㆍ반(半)합성 모노필라멘트를 포함한다]
#  - 전기식 조명용이나 신호용 기구(제8539호의 물품은 제외한다)ㆍ윈드스크린와이퍼(windscreen wiper)ㆍ제상기(defroster)ㆍ제무기(demister)(자전거용이나 자동차용으로 한정한다)
#  - 전기식의 즉시식ㆍ저장식 물가열기와 투입식 가열기, 난방기기와 토양가열기, 전기가열식 이용기기[예: 헤어드라이어ㆍ헤어컬러(hair curler)ㆍ컬링통히터(curling tong heater)], 손 건조기, 전기다리미, 그 밖의 가정용 전열기기, 전열용 저항체(제8545호의 것은 제외한다)
#  - 전동기와 발전기(발전세트는 제외한다)
#  - 전자공업에 사용하기 위하여 도프처리된(doped) 화학원소(디스크ㆍ웨이퍼 모양이나 이와 유사한 모양으로 한정한다), 전자공업에 사용하기 위하여 도프처리된(doped) 화학화합물
#  - 전화기(셀룰러 통신망용이나 그 밖의 무선통신망용의 스마트폰과 그 밖의 전화기를 포함한다)와 음성ㆍ영상이나 그 밖의 자료의 송신용ㆍ수신용 그 밖의 기기(근거리 통신망이나 원거리 통신망과 같은 유선ㆍ무선 통신망에서 통신하기 위한 기기를 포함하며, 제8443호ㆍ제8525호ㆍ제8527호ㆍ제8528호의 송신용ㆍ수신용 기기는 제외한다)
#  - 종이, 판지, 셀룰로오스워딩, 셀룰로오스섬유의 웹(web)[크기와는 관계 없이 롤 모양이나 직사각형(정사각형을 포함한다)의 시트(sheet) 모양으로서 도포ㆍ침투ㆍ피복ㆍ표면착색ㆍ표면장식ㆍ인쇄한 것으로 한정하며, 제4803호ㆍ제4809호ㆍ제4810호에 열거한 것은 제외한다]
#  - 천연고무ㆍ발라타(balata)ㆍ구타페르카(gutta-percha)ㆍ구아율(guayule)ㆍ치클(chicle)과 이와 유사한 천연 검(gum)[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다]
#  - 철이나 비합금강의 그 밖의 봉
#  - 철이나 비합금강의 그 밖의 봉[단조(鍛造)ㆍ열간(熱間)압연ㆍ열간인발(熱間引拔)ㆍ열간(熱間)압출보다 더 가공하지 않은 것으로 한정하고, 압연 후 꼬임가공된 것을 포함한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 미만인 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 열간(熱間)압연한 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  - 철이나 비합금강의 형강(形鋼)
#  - 축전지(격리판을 포함하며, 직사각형이나 정사각형인지에 상관없다)
#  - 카본지, 셀프복사지, 그 밖의 복사지나 전사지[등사원지나 오프셋 플레이트(offset plate)로 사용하는 도포지와 침투지를 포함하고, 인쇄한 것인지에 상관없으며 롤 모양이나 시트(sheet) 모양으로 한정한다]
#  - 텔레비전 수신기기를 갖추지 않은 모니터와 프로젝터, 텔레비전 수신용 기기(라디오 방송용 수신기기ㆍ음성이나 영상의 기록용 기기나 재생용 기기를 결합한 것인지에 상관없다)
#  - 한 면이나 양면을 도포한 종이와 판지[결합재가 있는지에 상관없으며 고령토(kaolin)[차이나 클레이(China clay)]나 그 밖의 무기물질을 도포한 것(그 밖의 다른 물질을 도포한 것은 제외한다)으로서 표면착색ㆍ표면장식ㆍ인쇄하였는지에 상관없으며 크기와는 관계없이 롤 모양이나 직사각형(정사각형을 포함한다)의 시트(sheet) 모양으로 한정한다]
#  - 합성모노필라멘트(67데시텍스 이상인 것으로서 횡단면의 치수가 1밀리미터 이하인 것으로 한정한다), 방직용 합성섬유재료의 스트립(strip)이나 이와 유사한 것[예: 인조스트로(straw)](시폭이 5밀리미터 이하인 것으로 한정한다)
#  - 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다)
#  - 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이, 셀룰로오스워딩ㆍ셀룰로오스섬유의 웹(web)[주름지거나(creped) 구겨진(crinkled) 것, 올록볼록한(embossed) 것, 구멍을 뚫은(perforated) 것, 착색한 것, 표면장식한 것, 인쇄한 것인지에 상관없으며 롤 모양이나 시트(sheet) 모양으로 한정한다]
#  - 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine paper)와 그 밖의 투명 광택지나 반투명 광택지[롤 모양이나 시트(sheet) 모양으로 한정한다]
#
# 🔹 클러스터 1 (총 2개 품목)
#  - 남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cape)ㆍ클록(cloak)ㆍ아노락(anorak)(스키재킷을 포함한다)ㆍ윈드치터(wind-cheater)ㆍ윈드재킷(wind-jacket)과 이와 유사한 의류(메리야스 편물과 뜨개질 편물로 한정하며, 제6103호의 것은 제외한다)
#  - 남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cape)ㆍ클록(cloak)ㆍ아노락(anorak)(스키재킷을 포함한다)ㆍ윈드치터(wind-cheater)ㆍ윈드재킷(wind-jacket)과 이와 유사한 의류(제6203호의 것은 제외한다)
#
# 🔹 클러스터 2 (총 14개 품목)
#  - 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric loss)식을 포함한다]과 그 밖의 공업용이나 실험실용의 전자유도식이나 유전손실(dielectric loss)식 가열기
#  - 그 밖의 차량[압축점화식 피스톤 내연기관(디젤이나 세미디젤)과 추진용 모터로서의 전동기를 둘 다 갖춘 것으로서, 외부 전원에 플러그를 꽂아 충전할 수 있는 방식의 것은 제외한다]
#  - 면도기ㆍ이발기ㆍ모발제거기[전동기를 갖춘 것으로 한정한다]
#  - 발전세트와 회전변환기
#  - 백금(가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#  - 실린더용량이 1,500시시 초과 3,000시시 이하인 것
#  - 실린더용량이 3,000시시를 초과하는 것
#  - 알루미늄광과 그 정광(精鑛)
#  - 이 류에 따로 분류되지 않은 기계류(고유의 기능을 가진 것으로 한정한다)
#  - 전기기계식의 가정용 기기(전동기를 갖춘 것으로 한정하며, 제8508호의 진공청소기는 제외한다)
#  - 전기식(전기발열에 따른 가스식을 포함한다)ㆍ레이저나 그 밖의 광선식ㆍ광자빔식ㆍ초음파식ㆍ전자빔식ㆍ자기펄스(magnetic pulse)식ㆍ플라즈마 아크(plasma arc)식 납땜용ㆍ땜질용이나 용접용 기기(절단기능이 있는지에 상관없다), 금속이나 서멧(cermet)의 가열분사용 전기식 기기
#  - 정형외과용 기기(목발ㆍ외과용 벨트와 탈장대를 포함한다), 골절 치료용 부목과 그 밖의 골절 치료구, 인공 인체 부분, 보청기, 결함ㆍ장애를 보정하기 위하여 착용하거나 휴대하거나 인체에 삽입하는 그 밖의 기기
#  - 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)
#  - 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, 제8512호의 조명기구는 제외한다)
#
# 🔹 클러스터 3 (총 1개 품목)
#  - 대두유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#
# 🔹 클러스터 4 (총 25개 품목)
#  - 구리광과 그 정광(精鑛)
#  - 그 밖의 차량(불꽃점화식 피스톤 내연기관과 추진용 모터로서의 전동기를 둘 다 갖춘 것으로서, 외부 전원에 플러그를 꽂아 충전할 수 있는 방식의 것으로 한정한다)
#  - 금(백금을 도금한 금을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#  - 대두(부수었는지에 상관없다)
#  - 도포하지 않은 종이와 판지(필기용, 인쇄용, 그 밖의 그래픽용으로 한정한다), 구멍을 뚫지 않은 펀치카드와 펀치테이프지[제4801호와 제4803호의 것은 제외하며, 크기와는 관계 없이 롤 모양이나 직사각형(정사각형을 포함한다) 시트(sheet) 모양으로 한정한다], 수제(手製) 종이와 판지
#  - 도포하지 않은 크라프트지와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 제4802호나 제4803호의 것은 제외한다]
#  - 밀과 메슬린(meslin)
#  - 베릴륨ㆍ크로뮴ㆍ하프늄ㆍ레늄ㆍ탈륨ㆍ카드뮴ㆍ게르마늄ㆍ바나듐ㆍ갈륨ㆍ인듐ㆍ니오븀(컬럼븀)과 이것으로 만든 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 부분품(제8501호나 제8502호의 기계에 전용되거나 주로 사용되는 것으로 한정한다)
#  - 서멧(cermet)과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 석유와 역청유(瀝靑油)(원유로 한정한다)
#  - 석탄과 석탄으로 제조한 연탄ㆍ조개탄(ovoid)과 이와 유사한 고체 연료
#  - 에틸렌의 중합체[일차제품(primary form)으로 한정한다]
#  - 유아용 의류와 그 부속품(메리야스 편물이나 뜨개질 편물로 한정한다)
#  - 의약품[혼합한 것인지에 상관없으며 치료용이나 예방용의 것으로서 일정한 투여량으로 한 것(피부 투여의 형식을 취한 것을 포함한다)과 소매용 모양이나 포장을 한 것으로 한정하며, 제3002호ㆍ제3005호ㆍ제3006호의 물품은 제외한다]
#  - 제재목[길이의 방향으로 쪼갠 것, 평삭(平削)한 것, 회전식으로 절단한 것으로서 두께가 6밀리미터를 초과하는 것으로 한정하며, 대패질ㆍ연마ㆍ엔드-조인트한(end-jointed) 것인지에 상관없다]
#  - 철광과 그 정광(精鑛)[배소(焙燒)한 황화철광을 포함한다]
#  - 철도용이나 궤도용 기관차나 차량의 부분품
#  - 철이나 비합금강의 봉[열간(熱間)압연한 것으로서 불규칙적으로 감은 코일 모양인 것으로 한정한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 미만인 것으로서 클래드(clad)ㆍ도금ㆍ도포한 것으로 한정한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 냉간압연(냉간환원)한 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 클래드(clad)ㆍ도금ㆍ도포한 것으로 한정한다]
#  - 티타늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 팜유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#  - 합성고무와 기름에서 제조한 팩티스(factice)[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다], 제4001호의 물품과 제4002호의 물품과의 혼합물[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다]
#
# 🔹 클러스터 5 (총 1개 품목)
#  - 농업용ㆍ원예용ㆍ임업용 기계(토양 정리용이나 경작용으로 한정한다)와 잔디용이나 운동장용 롤러
#
# 🔹 클러스터 6 (총 1개 품목)
#  - 그 밖의 항공기(예: 헬리콥터ㆍ비행기)(제8806호의 무인기를 제외한다), 우주선(인공위성을 포함한다)ㆍ서보비틀(suborbital) 발사체ㆍ우주선 발사체
#
# 🔹 클러스터 7 (총 1개 품목)
#  - 인조필라멘트사(재봉사는 제외하며, 소매용으로 한정한다)
#
# 🔹 클러스터 8 (총 2개 품목)
#  - 안티모니와 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 지르코늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#
# 🔹 클러스터 9 (총 2개 품목)
#  - 자주식(自走式) 철도용이나 궤도용 객차와 화차(제8604호의 것은 제외한다)
#  - 철강으로 만든 구조물(제9406호의 조립식 건축물은 제외한다)과 구조물의 부분품[예: 다리와 교량ㆍ수문ㆍ탑ㆍ격자주(格子柱)ㆍ지붕ㆍ지붕틀ㆍ문과 창 및 이들의 틀과 문지방ㆍ셔터ㆍ난간ㆍ기둥], 구조물용으로 가공한 철강으로 만든 판ㆍ대ㆍ봉ㆍ형재(形材)ㆍ관(管)과 이와 유사한 것

# %%
from scipy.spatial.distance import cdist
import numpy as np

# 품목명과 feature_tensor를 담은 전체 result_df
result_df = pd.DataFrame({
    '품목명': pivot_df.iloc[:, 1].values,
    '클러스터': y_pred1
})

# feature_tensor는 품목명 순서와 같은 순서라고 가정
result_df['feature'] = list(feature_tensor)

# 체인 순서 함수 정의
def build_chain_order(cluster_features, cluster_names):
    n = len(cluster_features)
    distances = cdist(cluster_features, cluster_features, metric='euclidean')
    np.fill_diagonal(distances, np.inf)  # 자기 자신은 제외

    visited = [False] * n
    chain = []

    # 시작은 가장 가까운 쌍 중 하나
    i, j = np.unravel_index(np.argmin(distances), distances.shape)
    chain.extend([i, j])
    visited[i] = visited[j] = True

    while len(chain) < n:
        last = chain[-1]
        dists = distances[last]
        for idx in np.argsort(dists):
            if not visited[idx]:
                chain.append(idx)
                visited[idx] = True
                break
    return [cluster_names[i] for i in chain]

# 클러스터별 체인 출력
for cluster_id, group in result_df.groupby('클러스터'):
    cluster_names = group['품목명'].tolist()
    cluster_features = np.stack(group['feature'].values)

    chain_order = build_chain_order(cluster_features, cluster_names)

    print(f"\n🔸 클러스터 {cluster_id} 체인 순서 (총 {len(chain_order)}개)")
    for i, name in enumerate(chain_order):
        print(f"{i+1:2d}. {name}")
# Out:
# 🔸 클러스터 0 체인 순서 (총 43개)
#  1. 따로 분류되지 않은 조제 식료품
#  2. 전기식 조명용이나 신호용 기구(제8539호의 물품은 제외한다)ㆍ윈드스크린와이퍼(windscreen wiper)ㆍ제상기(defroster)ㆍ제무기(demister)(자전거용이나 자동차용으로 한정한다)
#  3. 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다)
#  4. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 미만인 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  5. 종이, 판지, 셀룰로오스워딩, 셀룰로오스섬유의 웹(web)[크기와는 관계 없이 롤 모양이나 직사각형(정사각형을 포함한다)의 시트(sheet) 모양으로서 도포ㆍ침투ㆍ피복ㆍ표면착색ㆍ표면장식ㆍ인쇄한 것으로 한정하며, 제4803호ㆍ제4809호ㆍ제4810호에 열거한 것은 제외한다]
#  6. 기계요법용 기기, 마사지용 기기, 심리학적 적성검사용 기기, 오존 흡입기ㆍ산소 흡입기ㆍ에어로졸 치료기ㆍ인공호흡기나 그 밖의 치료용 호흡기기
#  7. 철이나 비합금강의 그 밖의 봉
#  8. 알루미늄의 괴(塊)
#  9. 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polarizing material)로 만든 판, 각종 재료로 만든 렌즈(콘택트렌즈를 포함한다)ㆍ프리즘ㆍ반사경과 그 밖의 광학소자로서 장착되지 않은 것(광학적으로 가공하지 않은 유리로 만든 광학소자는 제외한다)
# 10. 텔레비전 수신기기를 갖추지 않은 모니터와 프로젝터, 텔레비전 수신용 기기(라디오 방송용 수신기기ㆍ음성이나 영상의 기록용 기기나 재생용 기기를 결합한 것인지에 상관없다)
# 11. 실험실용ㆍ화학용이나 그 밖의 공업용 도자제품, 농업용 도자제 통과 이와 유사한 용기, 물품의 수송용ㆍ포장용으로 사용하는 도자제의 항아리ㆍ단지와 이와 유사한 제품
# 12. 한 면이나 양면을 도포한 종이와 판지[결합재가 있는지에 상관없으며 고령토(kaolin)[차이나 클레이(China clay)]나 그 밖의 무기물질을 도포한 것(그 밖의 다른 물질을 도포한 것은 제외한다)으로서 표면착색ㆍ표면장식ㆍ인쇄하였는지에 상관없으며 크기와는 관계없이 롤 모양이나 직사각형(정사각형을 포함한다)의 시트(sheet) 모양으로 한정한다]
# 13. 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine paper)와 그 밖의 투명 광택지나 반투명 광택지[롤 모양이나 시트(sheet) 모양으로 한정한다]
# 14. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 열간(熱間)압연한 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
# 15. 합성모노필라멘트(67데시텍스 이상인 것으로서 횡단면의 치수가 1밀리미터 이하인 것으로 한정한다), 방직용 합성섬유재료의 스트립(strip)이나 이와 유사한 것[예: 인조스트로(straw)](시폭이 5밀리미터 이하인 것으로 한정한다)
# 16. 내과용ㆍ외과용ㆍ치과용ㆍ수의과용 기기[신티그래픽(scintigraphic)식 진단기기ㆍ그 밖의 전기식 의료기기와 시력 검사기기를 포함한다]
# 17. 전기식의 즉시식ㆍ저장식 물가열기와 투입식 가열기, 난방기기와 토양가열기, 전기가열식 이용기기[예: 헤어드라이어ㆍ헤어컬러(hair curler)ㆍ컬링통히터(curling tong heater)], 손 건조기, 전기다리미, 그 밖의 가정용 전열기기, 전열용 저항체(제8545호의 것은 제외한다)
# 18. 재생ㆍ반(半)합성 필라멘트사[재봉사와 소매용은 제외하며, 67데시텍스 미만인 재생ㆍ반(半)합성 모노필라멘트를 포함한다]
# 19. 반도체 디바이스(예: 다이오드ㆍ트랜지스터ㆍ반도체 기반 트랜스듀서), 감광성 반도체 디바이스(광전지는 모듈에 조립되었거나 패널로 구성되었는지 여부와 관계없이 포함한다), 발광다이오드[(엘이디), 다른 발광다이오드와 결합되었는지 여부과 관계없이 포함한다], 장착된 압전기 결정소자
# 20. 엑스선이나 알파선ㆍ베타선ㆍ감마선ㆍ그 밖의 전리선을 사용하는 기기(내과용ㆍ외과용ㆍ치과용ㆍ수의과용인지에 상관없으며 방사선 사진용이나 방사선 치료용 기기ㆍ엑스선관과 그 밖의 엑스선 발생기ㆍ고압 발생기ㆍ조절반ㆍ스크린ㆍ검사용이나 치료용 테이블ㆍ의자와 이와 유사한 물품을 포함한다)
# 21. 옥수수
# 22. 원목[껍질ㆍ변재(邊材)를 벗긴 것인지 또는 거칠게 각을 뜬 것인지에 상관없다]
# 23. 전자공업에 사용하기 위하여 도프처리된(doped) 화학원소(디스크ㆍ웨이퍼 모양이나 이와 유사한 모양으로 한정한다), 전자공업에 사용하기 위하여 도프처리된(doped) 화학화합물
# 24. 은(금이나 백금을 도금한 은을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
# 25. 불꽃점화식이나 압축점화식 내연기관의 점화용ㆍ시동용 전기기기(예: 점화용 자석발전기ㆍ자석발전기ㆍ점화코일ㆍ점화플러그ㆍ예열플러그ㆍ시동전동기), 내연기관에 부속되는 발전기(예: 직류발전기ㆍ교류발전기)와 개폐기
# 26. 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이, 셀룰로오스워딩ㆍ셀룰로오스섬유의 웹(web)[주름지거나(creped) 구겨진(crinkled) 것, 올록볼록한(embossed) 것, 구멍을 뚫은(perforated) 것, 착색한 것, 표면장식한 것, 인쇄한 것인지에 상관없으며 롤 모양이나 시트(sheet) 모양으로 한정한다]
# 27. 그 밖의 호흡용 기기와 가스마스크(기계적인 부분품과 교환용 필터를 모두 갖추지 않은 보호용 마스크는 제외한다)
# 28. 그 밖의 무기산과 무기 비(非)금속 산화물
# 29. 철이나 비합금강의 형강(形鋼)
# 30. 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 이 류의 주 제3호의 것 이상의 가공을 하지 않은 것으로 한정한다]
# 31. 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 한정하며, 표면을 도포하거나 침투시킨 것은 제외하고, 내면을 보강했는지에 상관없다]
# 32. 축전지(격리판을 포함하며, 직사각형이나 정사각형인지에 상관없다)
# 33. 카본지, 셀프복사지, 그 밖의 복사지나 전사지[등사원지나 오프셋 플레이트(offset plate)로 사용하는 도포지와 침투지를 포함하고, 인쇄한 것인지에 상관없으며 롤 모양이나 시트(sheet) 모양으로 한정한다]
# 34. 철이나 비합금강의 그 밖의 봉[단조(鍛造)ㆍ열간(熱間)압연ㆍ열간인발(熱間引拔)ㆍ열간(熱間)압출보다 더 가공하지 않은 것으로 한정하고, 압연 후 꼬임가공된 것을 포함한다]
# 35. 그 밖의 차량(추진용 전동기만을 갖춘 것)
# 36. 전화기(셀룰러 통신망용이나 그 밖의 무선통신망용의 스마트폰과 그 밖의 전화기를 포함한다)와 음성ㆍ영상이나 그 밖의 자료의 송신용ㆍ수신용 그 밖의 기기(근거리 통신망이나 원거리 통신망과 같은 유선ㆍ무선 통신망에서 통신하기 위한 기기를 포함하며, 제8443호ㆍ제8525호ㆍ제8527호ㆍ제8528호의 송신용ㆍ수신용 기기는 제외한다)
# 37. 전동기와 발전기(발전세트는 제외한다)
# 38. 천연고무ㆍ발라타(balata)ㆍ구타페르카(gutta-percha)ㆍ구아율(guayule)ㆍ치클(chicle)과 이와 유사한 천연 검(gum)[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다]
# 39. 물결 모양으로 하거나(corrugated)(평면지가 붙은 것인지에 상관없다) 주름지거나(creped) 구겨지거나(crinkled) 올록볼록하거나(embossed) 구멍을 뚫은(perforated) 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 제4803호의 것은 제외한다]
# 40. 석유가스와 그 밖의 가스 상태의 탄화수소
# 41. 망간과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
# 42. 면[카드(card)하지도 코움(comb)하지도 않은 것으로 한정한다]
# 43. 니켈의 괴(塊)
#
# 🔸 클러스터 1 체인 순서 (총 2개)
#  1. 남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cape)ㆍ클록(cloak)ㆍ아노락(anorak)(스키재킷을 포함한다)ㆍ윈드치터(wind-cheater)ㆍ윈드재킷(wind-jacket)과 이와 유사한 의류(메리야스 편물과 뜨개질 편물로 한정하며, 제6103호의 것은 제외한다)
#  2. 남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cape)ㆍ클록(cloak)ㆍ아노락(anorak)(스키재킷을 포함한다)ㆍ윈드치터(wind-cheater)ㆍ윈드재킷(wind-jacket)과 이와 유사한 의류(제6203호의 것은 제외한다)
#
# 🔸 클러스터 2 체인 순서 (총 14개)
#  1. 정형외과용 기기(목발ㆍ외과용 벨트와 탈장대를 포함한다), 골절 치료용 부목과 그 밖의 골절 치료구, 인공 인체 부분, 보청기, 결함ㆍ장애를 보정하기 위하여 착용하거나 휴대하거나 인체에 삽입하는 그 밖의 기기
#  2. 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)
#  3. 실린더용량이 3,000시시를 초과하는 것
#  4. 이 류에 따로 분류되지 않은 기계류(고유의 기능을 가진 것으로 한정한다)
#  5. 전기식(전기발열에 따른 가스식을 포함한다)ㆍ레이저나 그 밖의 광선식ㆍ광자빔식ㆍ초음파식ㆍ전자빔식ㆍ자기펄스(magnetic pulse)식ㆍ플라즈마 아크(plasma arc)식 납땜용ㆍ땜질용이나 용접용 기기(절단기능이 있는지에 상관없다), 금속이나 서멧(cermet)의 가열분사용 전기식 기기
#  6. 실린더용량이 1,500시시 초과 3,000시시 이하인 것
#  7. 전기기계식의 가정용 기기(전동기를 갖춘 것으로 한정하며, 제8508호의 진공청소기는 제외한다)
#  8. 면도기ㆍ이발기ㆍ모발제거기[전동기를 갖춘 것으로 한정한다]
#  9. 그 밖의 차량[압축점화식 피스톤 내연기관(디젤이나 세미디젤)과 추진용 모터로서의 전동기를 둘 다 갖춘 것으로서, 외부 전원에 플러그를 꽂아 충전할 수 있는 방식의 것은 제외한다]
# 10. 백금(가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
# 11. 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, 제8512호의 조명기구는 제외한다)
# 12. 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric loss)식을 포함한다]과 그 밖의 공업용이나 실험실용의 전자유도식이나 유전손실(dielectric loss)식 가열기
# 13. 알루미늄광과 그 정광(精鑛)
# 14. 발전세트와 회전변환기
#
# 🔸 클러스터 3 체인 순서 (총 2개)
#  1. 대두유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#  2. 대두유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#
# 🔸 클러스터 4 체인 순서 (총 25개)
#  1. 철광과 그 정광(精鑛)[배소(焙燒)한 황화철광을 포함한다]
#  2. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 클래드(clad)ㆍ도금ㆍ도포한 것으로 한정한다]
#  3. 합성고무와 기름에서 제조한 팩티스(factice)[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다], 제4001호의 물품과 제4002호의 물품과의 혼합물[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다]
#  4. 에틸렌의 중합체[일차제품(primary form)으로 한정한다]
#  5. 밀과 메슬린(meslin)
#  6. 티타늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  7. 도포하지 않은 종이와 판지(필기용, 인쇄용, 그 밖의 그래픽용으로 한정한다), 구멍을 뚫지 않은 펀치카드와 펀치테이프지[제4801호와 제4803호의 것은 제외하며, 크기와는 관계 없이 롤 모양이나 직사각형(정사각형을 포함한다) 시트(sheet) 모양으로 한정한다], 수제(手製) 종이와 판지
#  8. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 미만인 것으로서 클래드(clad)ㆍ도금ㆍ도포한 것으로 한정한다]
#  9. 도포하지 않은 크라프트지와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 제4802호나 제4803호의 것은 제외한다]
# 10. 철도용이나 궤도용 기관차나 차량의 부분품
# 11. 대두(부수었는지에 상관없다)
# 12. 서멧(cermet)과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
# 13. 철이나 비합금강의 봉[열간(熱間)압연한 것으로서 불규칙적으로 감은 코일 모양인 것으로 한정한다]
# 14. 베릴륨ㆍ크로뮴ㆍ하프늄ㆍ레늄ㆍ탈륨ㆍ카드뮴ㆍ게르마늄ㆍ바나듐ㆍ갈륨ㆍ인듐ㆍ니오븀(컬럼븀)과 이것으로 만든 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
# 15. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 냉간압연(냉간환원)한 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
# 16. 부분품(제8501호나 제8502호의 기계에 전용되거나 주로 사용되는 것으로 한정한다)
# 17. 의약품[혼합한 것인지에 상관없으며 치료용이나 예방용의 것으로서 일정한 투여량으로 한 것(피부 투여의 형식을 취한 것을 포함한다)과 소매용 모양이나 포장을 한 것으로 한정하며, 제3002호ㆍ제3005호ㆍ제3006호의 물품은 제외한다]
# 18. 석유와 역청유(瀝靑油)(원유로 한정한다)
# 19. 석탄과 석탄으로 제조한 연탄ㆍ조개탄(ovoid)과 이와 유사한 고체 연료
# 20. 제재목[길이의 방향으로 쪼갠 것, 평삭(平削)한 것, 회전식으로 절단한 것으로서 두께가 6밀리미터를 초과하는 것으로 한정하며, 대패질ㆍ연마ㆍ엔드-조인트한(end-jointed) 것인지에 상관없다]
# 21. 구리광과 그 정광(精鑛)
# 22. 그 밖의 차량(불꽃점화식 피스톤 내연기관과 추진용 모터로서의 전동기를 둘 다 갖춘 것으로서, 외부 전원에 플러그를 꽂아 충전할 수 있는 방식의 것으로 한정한다)
# 23. 금(백금을 도금한 금을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
# 24. 팜유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
# 25. 유아용 의류와 그 부속품(메리야스 편물이나 뜨개질 편물로 한정한다)
#
# 🔸 클러스터 5 체인 순서 (총 2개)
#  1. 농업용ㆍ원예용ㆍ임업용 기계(토양 정리용이나 경작용으로 한정한다)와 잔디용이나 운동장용 롤러
#  2. 농업용ㆍ원예용ㆍ임업용 기계(토양 정리용이나 경작용으로 한정한다)와 잔디용이나 운동장용 롤러
#
# 🔸 클러스터 6 체인 순서 (총 2개)
#  1. 그 밖의 항공기(예: 헬리콥터ㆍ비행기)(제8806호의 무인기를 제외한다), 우주선(인공위성을 포함한다)ㆍ서보비틀(suborbital) 발사체ㆍ우주선 발사체
#  2. 그 밖의 항공기(예: 헬리콥터ㆍ비행기)(제8806호의 무인기를 제외한다), 우주선(인공위성을 포함한다)ㆍ서보비틀(suborbital) 발사체ㆍ우주선 발사체
#
# 🔸 클러스터 7 체인 순서 (총 2개)
#  1. 인조필라멘트사(재봉사는 제외하며, 소매용으로 한정한다)
#  2. 인조필라멘트사(재봉사는 제외하며, 소매용으로 한정한다)
#
# 🔸 클러스터 8 체인 순서 (총 2개)
#  1. 안티모니와 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  2. 지르코늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#
# 🔸 클러스터 9 체인 순서 (총 2개)
#  1. 자주식(自走式) 철도용이나 궤도용 객차와 화차(제8604호의 것은 제외한다)
#  2. 철강으로 만든 구조물(제9406호의 조립식 건축물은 제외한다)과 구조물의 부분품[예: 다리와 교량ㆍ수문ㆍ탑ㆍ격자주(格子柱)ㆍ지붕ㆍ지붕틀ㆍ문과 창 및 이들의 틀과 문지방ㆍ셔터ㆍ난간ㆍ기둥], 구조물용으로 가공한 철강으로 만든 판ㆍ대ㆍ봉ㆍ형재(形材)ㆍ관(管)과 이와 유사한 것

# %%
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import torch

# %%
pca = PCA(n_components=2)
X_pca1 = pca.fit_transform(feature_tensor)

# %%
X_pca1
# Out:
# array([[-0.20744551, -0.09223055],
#        [ 0.32792088, -1.10645817],
#        [ 0.21810068,  0.76677747],
#        [ 0.30746658,  0.56497546],
#        [-0.52316292,  0.40658464],
#        [-0.94040059,  1.37994418],
#        [-1.49533305, -0.19871566],
#        [-0.20859161,  0.44339188],
#        [ 0.50827285, -2.30904771],
#        [ 3.27223007, -4.30996663],
#        [-0.7720147 ,  1.17204916],
#        [-1.0688207 ,  0.04137317],
#        [-0.01446555, -0.22471033],
#        [ 9.5746936 ,  1.55699385],
#        [10.90024936,  1.31370888],
#        [-0.15847057, -0.02121592],
#        [-4.62421557,  2.2265574 ],
#        [-2.49530372,  1.59719778],
#        [-0.79110429,  0.70525724],
#        [-0.1729857 , -3.45604913],
#        [-0.08956951,  0.46466754],
#        [-0.1764493 ,  0.39281967],
#        [-0.18253855,  0.27130138],
#        [-0.1627987 ,  1.57815625],
#        [-0.99915633,  0.38958515],
#        [ 0.03102721, -0.97305007],
#        [-0.35819951,  0.23870252],
#        [-0.29968204,  0.77966076],
#        [ 0.2094878 ,  0.30822794],
#        [-0.6483716 , -2.2238143 ],
#        [-0.92411203, -1.58729065],
#        [-1.04529625,  2.10287252],
#        [ 0.58606706,  0.75302942],
#        [-0.31665164,  0.27993237],
#        [-0.91412948,  0.03893555],
#        [ 0.24024244,  0.65322017],
#        [ 0.37908021,  0.45509474],
#        [-0.05354841,  1.55130773],
#        [-0.14694278, -0.58474584],
#        [-0.55535139, -1.75584927],
#        [ 0.10391889,  0.42869529],
#        [ 2.47508948, -2.23296895],
#        [-1.13345614, -2.62812069],
#        [-0.10984946,  0.6146674 ],
#        [-0.18991597,  1.1579206 ],
#        [ 0.12053874, -0.32311155],
#        [ 0.24061159, -0.37717504],
#        [-0.12365566, -0.6495576 ],
#        [ 1.94561371,  2.93699672],
#        [ 0.53796906, -0.11635325],
#        [-0.25065052,  0.38369296],
#        [-0.37104014, -1.44512992],
#        [-0.20728372, -5.1794599 ],
#        [-0.88989646, -4.44230972],
#        [ 0.03460871,  0.09110652],
#        [ 0.04304687, -0.90565815],
#        [-0.13735277,  0.40973698],
#        [-0.62983556, -1.12639543],
#        [-0.39489847, -0.50090733],
#        [ 0.55006054,  0.39953863],
#        [ 0.27383385, -0.24422157],
#        [ 0.58469689, -0.37293303],
#        [-0.50340582, -1.00906642],
#        [ 1.06597613,  0.24003553],
#        [ 0.03625707, -0.07202627],
#        [ 0.58040111, -0.02656754],
#        [ 1.17894591, -0.53552048],
#        [-1.36496962, -3.29573172],
#        [ 0.14725426,  1.05449907],
#        [-0.55523639,  0.42566021],
#        [-0.02826883,  0.03065399],
#        [-0.60808287,  0.38574509],
#        [-1.30945813,  1.42784786],
#        [-0.45923532, -0.04379121],
#        [-0.66413196,  0.60351785],
#        [-0.0231182 ,  1.42957722],
#        [-0.46139908,  0.69039722],
#        [-0.34790797,  1.19385172],
#        [-1.03127304,  1.37732137],
#        [ 0.2040451 , -0.02220215],
#        [-0.27479717,  0.58224572],
#        [-0.18359335,  0.75637819],
#        [ 0.05331001,  0.16688596],
#        [-1.67232331,  3.40377278],
#        [-0.12256315,  0.78571365],
#        [-0.52542002,  1.16122571],
#        [-0.2404143 ,  0.04544749],
#        [-0.30853499,  0.52496409],
#        [-0.47850791, -1.00798621],
#        [-0.7006651 ,  1.10584657],
#        [-0.24041081,  0.75393335],
#        [ 0.15564753, -1.59986219]])

# %%
plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_pca1[:, 0], X_pca1[:, 1], c=y_pred1, cmap='tab20', s=50)
plt.title("PCA of Clustered Data", fontsize=16)
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.colorbar(scatter, label='Cluster ID')
plt.grid(True)
plt.show()

# %%
import numpy as np

# %%
common_params = {
    "n_init": 10,
    "random_state": 170,

}

# %%
pca2 = PCA(n_components=4)
X_pca2 = pca2.fit_transform(feature_tensor)
from sklearn.metrics import silhouette_score

scores = []
K_range = range(2, 15)  # silhouette
for k in K_range:
    labels = KMeans(n_clusters=k, **common_params).fit_predict(X_pca2)
    score = silhouette_score(X_pca2, labels)
    scores.append(score)

plt.plot(K_range, scores, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method')
plt.show()

# %%
y_pred2 = KMeans(n_clusters=13, **common_params).fit_predict(X_pca2)

# %%
# 'pivot_df'의 첫 번째 열이 '품목명'이라고 가정
품목명_series = pivot_df.iloc[:, 1]

# 클러스터 결과를 붙이기
result_df = pd.DataFrame({
    '품목명': 품목명_series,
    '클러스터': y_pred2
})

# 클러스터별 품목 리스트 출력
for cluster_id, group in result_df.groupby('클러스터'):
    print(f"\n🔹 클러스터 {cluster_id} (총 {len(group)}개 품목)")
    for name in group['품목명']:
        print(f" - {name}")
# Out:
# 🔹 클러스터 0 (총 42개 품목)
#  - 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polarizing material)로 만든 판, 각종 재료로 만든 렌즈(콘택트렌즈를 포함한다)ㆍ프리즘ㆍ반사경과 그 밖의 광학소자로서 장착되지 않은 것(광학적으로 가공하지 않은 유리로 만든 광학소자는 제외한다)
#  - 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 이 류의 주 제3호의 것 이상의 가공을 하지 않은 것으로 한정한다]
#  - 그 밖의 차량(추진용 전동기만을 갖춘 것)
#  - 내과용ㆍ외과용ㆍ치과용ㆍ수의과용 기기[신티그래픽(scintigraphic)식 진단기기ㆍ그 밖의 전기식 의료기기와 시력 검사기기를 포함한다]
#  - 도포하지 않은 종이와 판지(필기용, 인쇄용, 그 밖의 그래픽용으로 한정한다), 구멍을 뚫지 않은 펀치카드와 펀치테이프지[제4801호와 제4803호의 것은 제외하며, 크기와는 관계 없이 롤 모양이나 직사각형(정사각형을 포함한다) 시트(sheet) 모양으로 한정한다], 수제(手製) 종이와 판지
#  - 도포하지 않은 크라프트지와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 제4802호나 제4803호의 것은 제외한다]
#  - 따로 분류되지 않은 조제 식료품
#  - 면[카드(card)하지도 코움(comb)하지도 않은 것으로 한정한다]
#  - 물결 모양으로 하거나(corrugated)(평면지가 붙은 것인지에 상관없다) 주름지거나(creped) 구겨지거나(crinkled) 올록볼록하거나(embossed) 구멍을 뚫은(perforated) 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 제4803호의 것은 제외한다]
#  - 밀과 메슬린(meslin)
#  - 반도체 디바이스(예: 다이오드ㆍ트랜지스터ㆍ반도체 기반 트랜스듀서), 감광성 반도체 디바이스(광전지는 모듈에 조립되었거나 패널로 구성되었는지 여부와 관계없이 포함한다), 발광다이오드[(엘이디), 다른 발광다이오드와 결합되었는지 여부과 관계없이 포함한다], 장착된 압전기 결정소자
#  - 부분품(제8501호나 제8502호의 기계에 전용되거나 주로 사용되는 것으로 한정한다)
#  - 불꽃점화식이나 압축점화식 내연기관의 점화용ㆍ시동용 전기기기(예: 점화용 자석발전기ㆍ자석발전기ㆍ점화코일ㆍ점화플러그ㆍ예열플러그ㆍ시동전동기), 내연기관에 부속되는 발전기(예: 직류발전기ㆍ교류발전기)와 개폐기
#  - 서멧(cermet)과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 석유와 역청유(瀝靑油)(원유로 한정한다)
#  - 석탄과 석탄으로 제조한 연탄ㆍ조개탄(ovoid)과 이와 유사한 고체 연료
#  - 실험실용ㆍ화학용이나 그 밖의 공업용 도자제품, 농업용 도자제 통과 이와 유사한 용기, 물품의 수송용ㆍ포장용으로 사용하는 도자제의 항아리ㆍ단지와 이와 유사한 제품
#  - 알루미늄의 괴(塊)
#  - 에틸렌의 중합체[일차제품(primary form)으로 한정한다]
#  - 의약품[혼합한 것인지에 상관없으며 치료용이나 예방용의 것으로서 일정한 투여량으로 한 것(피부 투여의 형식을 취한 것을 포함한다)과 소매용 모양이나 포장을 한 것으로 한정하며, 제3002호ㆍ제3005호ㆍ제3006호의 물품은 제외한다]
#  - 재생ㆍ반(半)합성 필라멘트사[재봉사와 소매용은 제외하며, 67데시텍스 미만인 재생ㆍ반(半)합성 모노필라멘트를 포함한다]
#  - 전기식 조명용이나 신호용 기구(제8539호의 물품은 제외한다)ㆍ윈드스크린와이퍼(windscreen wiper)ㆍ제상기(defroster)ㆍ제무기(demister)(자전거용이나 자동차용으로 한정한다)
#  - 전동기와 발전기(발전세트는 제외한다)
#  - 종이, 판지, 셀룰로오스워딩, 셀룰로오스섬유의 웹(web)[크기와는 관계 없이 롤 모양이나 직사각형(정사각형을 포함한다)의 시트(sheet) 모양으로서 도포ㆍ침투ㆍ피복ㆍ표면착색ㆍ표면장식ㆍ인쇄한 것으로 한정하며, 제4803호ㆍ제4809호ㆍ제4810호에 열거한 것은 제외한다]
#  - 철광과 그 정광(精鑛)[배소(焙燒)한 황화철광을 포함한다]
#  - 철도용이나 궤도용 기관차나 차량의 부분품
#  - 철이나 비합금강의 그 밖의 봉
#  - 철이나 비합금강의 그 밖의 봉[단조(鍛造)ㆍ열간(熱間)압연ㆍ열간인발(熱間引拔)ㆍ열간(熱間)압출보다 더 가공하지 않은 것으로 한정하고, 압연 후 꼬임가공된 것을 포함한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 미만인 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 미만인 것으로서 클래드(clad)ㆍ도금ㆍ도포한 것으로 한정한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 냉간압연(냉간환원)한 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 열간(熱間)압연한 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 클래드(clad)ㆍ도금ㆍ도포한 것으로 한정한다]
#  - 축전지(격리판을 포함하며, 직사각형이나 정사각형인지에 상관없다)
#  - 카본지, 셀프복사지, 그 밖의 복사지나 전사지[등사원지나 오프셋 플레이트(offset plate)로 사용하는 도포지와 침투지를 포함하고, 인쇄한 것인지에 상관없으며 롤 모양이나 시트(sheet) 모양으로 한정한다]
#  - 텔레비전 수신기기를 갖추지 않은 모니터와 프로젝터, 텔레비전 수신용 기기(라디오 방송용 수신기기ㆍ음성이나 영상의 기록용 기기나 재생용 기기를 결합한 것인지에 상관없다)
#  - 티타늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 한 면이나 양면을 도포한 종이와 판지[결합재가 있는지에 상관없으며 고령토(kaolin)[차이나 클레이(China clay)]나 그 밖의 무기물질을 도포한 것(그 밖의 다른 물질을 도포한 것은 제외한다)으로서 표면착색ㆍ표면장식ㆍ인쇄하였는지에 상관없으며 크기와는 관계없이 롤 모양이나 직사각형(정사각형을 포함한다)의 시트(sheet) 모양으로 한정한다]
#  - 합성고무와 기름에서 제조한 팩티스(factice)[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다], 제4001호의 물품과 제4002호의 물품과의 혼합물[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다]
#  - 합성모노필라멘트(67데시텍스 이상인 것으로서 횡단면의 치수가 1밀리미터 이하인 것으로 한정한다), 방직용 합성섬유재료의 스트립(strip)이나 이와 유사한 것[예: 인조스트로(straw)](시폭이 5밀리미터 이하인 것으로 한정한다)
#  - 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다)
#  - 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine paper)와 그 밖의 투명 광택지나 반투명 광택지[롤 모양이나 시트(sheet) 모양으로 한정한다]
#
# 🔹 클러스터 1 (총 1개 품목)
#  - 유아용 의류와 그 부속품(메리야스 편물이나 뜨개질 편물로 한정한다)
#
# 🔹 클러스터 2 (총 2개 품목)
#  - 대두유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#  - 알루미늄광과 그 정광(精鑛)
#
# 🔹 클러스터 3 (총 2개 품목)
#  - 남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cape)ㆍ클록(cloak)ㆍ아노락(anorak)(스키재킷을 포함한다)ㆍ윈드치터(wind-cheater)ㆍ윈드재킷(wind-jacket)과 이와 유사한 의류(메리야스 편물과 뜨개질 편물로 한정하며, 제6103호의 것은 제외한다)
#  - 남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cape)ㆍ클록(cloak)ㆍ아노락(anorak)(스키재킷을 포함한다)ㆍ윈드치터(wind-cheater)ㆍ윈드재킷(wind-jacket)과 이와 유사한 의류(제6203호의 것은 제외한다)
#
# 🔹 클러스터 4 (총 9개 품목)
#  - 그 밖의 무기산과 무기 비(非)금속 산화물
#  - 그 밖의 호흡용 기기와 가스마스크(기계적인 부분품과 교환용 필터를 모두 갖추지 않은 보호용 마스크는 제외한다)
#  - 니켈의 괴(塊)
#  - 망간과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 베릴륨ㆍ크로뮴ㆍ하프늄ㆍ레늄ㆍ탈륨ㆍ카드뮴ㆍ게르마늄ㆍ바나듐ㆍ갈륨ㆍ인듐ㆍ니오븀(컬럼븀)과 이것으로 만든 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 석유가스와 그 밖의 가스 상태의 탄화수소
#  - 철이나 비합금강의 봉[열간(熱間)압연한 것으로서 불규칙적으로 감은 코일 모양인 것으로 한정한다]
#  - 철이나 비합금강의 형강(形鋼)
#  - 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이, 셀룰로오스워딩ㆍ셀룰로오스섬유의 웹(web)[주름지거나(creped) 구겨진(crinkled) 것, 올록볼록한(embossed) 것, 구멍을 뚫은(perforated) 것, 착색한 것, 표면장식한 것, 인쇄한 것인지에 상관없으며 롤 모양이나 시트(sheet) 모양으로 한정한다]
#
# 🔹 클러스터 5 (총 3개 품목)
#  - 인조필라멘트사(재봉사는 제외하며, 소매용으로 한정한다)
#  - 자주식(自走式) 철도용이나 궤도용 객차와 화차(제8604호의 것은 제외한다)
#  - 철강으로 만든 구조물(제9406호의 조립식 건축물은 제외한다)과 구조물의 부분품[예: 다리와 교량ㆍ수문ㆍ탑ㆍ격자주(格子柱)ㆍ지붕ㆍ지붕틀ㆍ문과 창 및 이들의 틀과 문지방ㆍ셔터ㆍ난간ㆍ기둥], 구조물용으로 가공한 철강으로 만든 판ㆍ대ㆍ봉ㆍ형재(形材)ㆍ관(管)과 이와 유사한 것
#
# 🔹 클러스터 6 (총 3개 품목)
#  - 그 밖의 차량[압축점화식 피스톤 내연기관(디젤이나 세미디젤)과 추진용 모터로서의 전동기를 둘 다 갖춘 것으로서, 외부 전원에 플러그를 꽂아 충전할 수 있는 방식의 것은 제외한다]
#  - 발전세트와 회전변환기
#  - 백금(가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#
# 🔹 클러스터 7 (총 1개 품목)
#  - 그 밖의 항공기(예: 헬리콥터ㆍ비행기)(제8806호의 무인기를 제외한다), 우주선(인공위성을 포함한다)ㆍ서보비틀(suborbital) 발사체ㆍ우주선 발사체
#
# 🔹 클러스터 8 (총 1개 품목)
#  - 농업용ㆍ원예용ㆍ임업용 기계(토양 정리용이나 경작용으로 한정한다)와 잔디용이나 운동장용 롤러
#
# 🔹 클러스터 9 (총 8개 품목)
#  - 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 한정하며, 표면을 도포하거나 침투시킨 것은 제외하고, 내면을 보강했는지에 상관없다]
#  - 구리광과 그 정광(精鑛)
#  - 그 밖의 차량(불꽃점화식 피스톤 내연기관과 추진용 모터로서의 전동기를 둘 다 갖춘 것으로서, 외부 전원에 플러그를 꽂아 충전할 수 있는 방식의 것으로 한정한다)
#  - 금(백금을 도금한 금을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#  - 대두(부수었는지에 상관없다)
#  - 전기기계식의 가정용 기기(전동기를 갖춘 것으로 한정하며, 제8508호의 진공청소기는 제외한다)
#  - 제재목[길이의 방향으로 쪼갠 것, 평삭(平削)한 것, 회전식으로 절단한 것으로서 두께가 6밀리미터를 초과하는 것으로 한정하며, 대패질ㆍ연마ㆍ엔드-조인트한(end-jointed) 것인지에 상관없다]
#  - 지르코늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#
# 🔹 클러스터 10 (총 18개 품목)
#  - 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric loss)식을 포함한다]과 그 밖의 공업용이나 실험실용의 전자유도식이나 유전손실(dielectric loss)식 가열기
#  - 기계요법용 기기, 마사지용 기기, 심리학적 적성검사용 기기, 오존 흡입기ㆍ산소 흡입기ㆍ에어로졸 치료기ㆍ인공호흡기나 그 밖의 치료용 호흡기기
#  - 면도기ㆍ이발기ㆍ모발제거기[전동기를 갖춘 것으로 한정한다]
#  - 실린더용량이 1,500시시 초과 3,000시시 이하인 것
#  - 실린더용량이 3,000시시를 초과하는 것
#  - 엑스선이나 알파선ㆍ베타선ㆍ감마선ㆍ그 밖의 전리선을 사용하는 기기(내과용ㆍ외과용ㆍ치과용ㆍ수의과용인지에 상관없으며 방사선 사진용이나 방사선 치료용 기기ㆍ엑스선관과 그 밖의 엑스선 발생기ㆍ고압 발생기ㆍ조절반ㆍ스크린ㆍ검사용이나 치료용 테이블ㆍ의자와 이와 유사한 물품을 포함한다)
#  - 옥수수
#  - 원목[껍질ㆍ변재(邊材)를 벗긴 것인지 또는 거칠게 각을 뜬 것인지에 상관없다]
#  - 은(금이나 백금을 도금한 은을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#  - 이 류에 따로 분류되지 않은 기계류(고유의 기능을 가진 것으로 한정한다)
#  - 전기식(전기발열에 따른 가스식을 포함한다)ㆍ레이저나 그 밖의 광선식ㆍ광자빔식ㆍ초음파식ㆍ전자빔식ㆍ자기펄스(magnetic pulse)식ㆍ플라즈마 아크(plasma arc)식 납땜용ㆍ땜질용이나 용접용 기기(절단기능이 있는지에 상관없다), 금속이나 서멧(cermet)의 가열분사용 전기식 기기
#  - 전기식의 즉시식ㆍ저장식 물가열기와 투입식 가열기, 난방기기와 토양가열기, 전기가열식 이용기기[예: 헤어드라이어ㆍ헤어컬러(hair curler)ㆍ컬링통히터(curling tong heater)], 손 건조기, 전기다리미, 그 밖의 가정용 전열기기, 전열용 저항체(제8545호의 것은 제외한다)
#  - 전자공업에 사용하기 위하여 도프처리된(doped) 화학원소(디스크ㆍ웨이퍼 모양이나 이와 유사한 모양으로 한정한다), 전자공업에 사용하기 위하여 도프처리된(doped) 화학화합물
#  - 전화기(셀룰러 통신망용이나 그 밖의 무선통신망용의 스마트폰과 그 밖의 전화기를 포함한다)와 음성ㆍ영상이나 그 밖의 자료의 송신용ㆍ수신용 그 밖의 기기(근거리 통신망이나 원거리 통신망과 같은 유선ㆍ무선 통신망에서 통신하기 위한 기기를 포함하며, 제8443호ㆍ제8525호ㆍ제8527호ㆍ제8528호의 송신용ㆍ수신용 기기는 제외한다)
#  - 정형외과용 기기(목발ㆍ외과용 벨트와 탈장대를 포함한다), 골절 치료용 부목과 그 밖의 골절 치료구, 인공 인체 부분, 보청기, 결함ㆍ장애를 보정하기 위하여 착용하거나 휴대하거나 인체에 삽입하는 그 밖의 기기
#  - 천연고무ㆍ발라타(balata)ㆍ구타페르카(gutta-percha)ㆍ구아율(guayule)ㆍ치클(chicle)과 이와 유사한 천연 검(gum)[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다]
#  - 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)
#  - 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, 제8512호의 조명기구는 제외한다)
#
# 🔹 클러스터 11 (총 1개 품목)
#  - 팜유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#
# 🔹 클러스터 12 (총 1개 품목)
#  - 안티모니와 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]

# %%
from scipy.spatial.distance import cdist
import numpy as np

# 품목명과 feature_tensor를 담은 전체 result_df
result_df = pd.DataFrame({
    '품목명': pivot_df.iloc[:, 1].values,
    '클러스터': y_pred2
})

# feature_tensor는 품목명 순서와 같은 순서라고 가정
result_df['feature'] = list(feature_tensor)

# 체인 순서 함수 정의
def build_chain_order(cluster_features, cluster_names):
    n = len(cluster_features)
    distances = cdist(cluster_features, cluster_features, metric='euclidean')
    np.fill_diagonal(distances, np.inf)  # 자기 자신은 제외

    visited = [False] * n
    chain = []

    # 시작은 가장 가까운 쌍 중 하나
    i, j = np.unravel_index(np.argmin(distances), distances.shape)
    chain.extend([i, j])
    visited[i] = visited[j] = True

    while len(chain) < n:
        last = chain[-1]
        dists = distances[last]
        for idx in np.argsort(dists):
            if not visited[idx]:
                chain.append(idx)
                visited[idx] = True
                break
    return [cluster_names[i] for i in chain]

# 클러스터별 체인 출력
for cluster_id, group in result_df.groupby('클러스터'):
    cluster_names = group['품목명'].tolist()
    cluster_features = np.stack(group['feature'].values)

    chain_order = build_chain_order(cluster_features, cluster_names)

    print(f"\n🔸 클러스터 {cluster_id} 체인 순서 (총 {len(chain_order)}개)")
    for i, name in enumerate(chain_order):
        print(f"{i+1:2d}. {name}")
# Out:
# 🔸 클러스터 0 체인 순서 (총 42개)
#  1. 따로 분류되지 않은 조제 식료품
#  2. 전기식 조명용이나 신호용 기구(제8539호의 물품은 제외한다)ㆍ윈드스크린와이퍼(windscreen wiper)ㆍ제상기(defroster)ㆍ제무기(demister)(자전거용이나 자동차용으로 한정한다)
#  3. 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다)
#  4. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 미만인 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  5. 종이, 판지, 셀룰로오스워딩, 셀룰로오스섬유의 웹(web)[크기와는 관계 없이 롤 모양이나 직사각형(정사각형을 포함한다)의 시트(sheet) 모양으로서 도포ㆍ침투ㆍ피복ㆍ표면착색ㆍ표면장식ㆍ인쇄한 것으로 한정하며, 제4803호ㆍ제4809호ㆍ제4810호에 열거한 것은 제외한다]
#  6. 철이나 비합금강의 그 밖의 봉
#  7. 알루미늄의 괴(塊)
#  8. 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polarizing material)로 만든 판, 각종 재료로 만든 렌즈(콘택트렌즈를 포함한다)ㆍ프리즘ㆍ반사경과 그 밖의 광학소자로서 장착되지 않은 것(광학적으로 가공하지 않은 유리로 만든 광학소자는 제외한다)
#  9. 텔레비전 수신기기를 갖추지 않은 모니터와 프로젝터, 텔레비전 수신용 기기(라디오 방송용 수신기기ㆍ음성이나 영상의 기록용 기기나 재생용 기기를 결합한 것인지에 상관없다)
# 10. 실험실용ㆍ화학용이나 그 밖의 공업용 도자제품, 농업용 도자제 통과 이와 유사한 용기, 물품의 수송용ㆍ포장용으로 사용하는 도자제의 항아리ㆍ단지와 이와 유사한 제품
# 11. 한 면이나 양면을 도포한 종이와 판지[결합재가 있는지에 상관없으며 고령토(kaolin)[차이나 클레이(China clay)]나 그 밖의 무기물질을 도포한 것(그 밖의 다른 물질을 도포한 것은 제외한다)으로서 표면착색ㆍ표면장식ㆍ인쇄하였는지에 상관없으며 크기와는 관계없이 롤 모양이나 직사각형(정사각형을 포함한다)의 시트(sheet) 모양으로 한정한다]
# 12. 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine paper)와 그 밖의 투명 광택지나 반투명 광택지[롤 모양이나 시트(sheet) 모양으로 한정한다]
# 13. 밀과 메슬린(meslin)
# 14. 티타늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
# 15. 도포하지 않은 종이와 판지(필기용, 인쇄용, 그 밖의 그래픽용으로 한정한다), 구멍을 뚫지 않은 펀치카드와 펀치테이프지[제4801호와 제4803호의 것은 제외하며, 크기와는 관계 없이 롤 모양이나 직사각형(정사각형을 포함한다) 시트(sheet) 모양으로 한정한다], 수제(手製) 종이와 판지
# 16. 합성모노필라멘트(67데시텍스 이상인 것으로서 횡단면의 치수가 1밀리미터 이하인 것으로 한정한다), 방직용 합성섬유재료의 스트립(strip)이나 이와 유사한 것[예: 인조스트로(straw)](시폭이 5밀리미터 이하인 것으로 한정한다)
# 17. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 열간(熱間)압연한 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
# 18. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 클래드(clad)ㆍ도금ㆍ도포한 것으로 한정한다]
# 19. 철광과 그 정광(精鑛)[배소(焙燒)한 황화철광을 포함한다]
# 20. 에틸렌의 중합체[일차제품(primary form)으로 한정한다]
# 21. 합성고무와 기름에서 제조한 팩티스(factice)[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다], 제4001호의 물품과 제4002호의 물품과의 혼합물[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다]
# 22. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 미만인 것으로서 클래드(clad)ㆍ도금ㆍ도포한 것으로 한정한다]
# 23. 카본지, 셀프복사지, 그 밖의 복사지나 전사지[등사원지나 오프셋 플레이트(offset plate)로 사용하는 도포지와 침투지를 포함하고, 인쇄한 것인지에 상관없으며 롤 모양이나 시트(sheet) 모양으로 한정한다]
# 24. 축전지(격리판을 포함하며, 직사각형이나 정사각형인지에 상관없다)
# 25. 내과용ㆍ외과용ㆍ치과용ㆍ수의과용 기기[신티그래픽(scintigraphic)식 진단기기ㆍ그 밖의 전기식 의료기기와 시력 검사기기를 포함한다]
# 26. 재생ㆍ반(半)합성 필라멘트사[재봉사와 소매용은 제외하며, 67데시텍스 미만인 재생ㆍ반(半)합성 모노필라멘트를 포함한다]
# 27. 반도체 디바이스(예: 다이오드ㆍ트랜지스터ㆍ반도체 기반 트랜스듀서), 감광성 반도체 디바이스(광전지는 모듈에 조립되었거나 패널로 구성되었는지 여부와 관계없이 포함한다), 발광다이오드[(엘이디), 다른 발광다이오드와 결합되었는지 여부과 관계없이 포함한다], 장착된 압전기 결정소자
# 28. 전동기와 발전기(발전세트는 제외한다)
# 29. 불꽃점화식이나 압축점화식 내연기관의 점화용ㆍ시동용 전기기기(예: 점화용 자석발전기ㆍ자석발전기ㆍ점화코일ㆍ점화플러그ㆍ예열플러그ㆍ시동전동기), 내연기관에 부속되는 발전기(예: 직류발전기ㆍ교류발전기)와 개폐기
# 30. 그 밖의 차량(추진용 전동기만을 갖춘 것)
# 31. 철이나 비합금강의 그 밖의 봉[단조(鍛造)ㆍ열간(熱間)압연ㆍ열간인발(熱間引拔)ㆍ열간(熱間)압출보다 더 가공하지 않은 것으로 한정하고, 압연 후 꼬임가공된 것을 포함한다]
# 32. 의약품[혼합한 것인지에 상관없으며 치료용이나 예방용의 것으로서 일정한 투여량으로 한 것(피부 투여의 형식을 취한 것을 포함한다)과 소매용 모양이나 포장을 한 것으로 한정하며, 제3002호ㆍ제3005호ㆍ제3006호의 물품은 제외한다]
# 33. 부분품(제8501호나 제8502호의 기계에 전용되거나 주로 사용되는 것으로 한정한다)
# 34. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 냉간압연(냉간환원)한 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
# 35. 도포하지 않은 크라프트지와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 제4802호나 제4803호의 것은 제외한다]
# 36. 철도용이나 궤도용 기관차나 차량의 부분품
# 37. 서멧(cermet)과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
# 38. 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 이 류의 주 제3호의 것 이상의 가공을 하지 않은 것으로 한정한다]
# 39. 물결 모양으로 하거나(corrugated)(평면지가 붙은 것인지에 상관없다) 주름지거나(creped) 구겨지거나(crinkled) 올록볼록하거나(embossed) 구멍을 뚫은(perforated) 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 제4803호의 것은 제외한다]
# 40. 석유와 역청유(瀝靑油)(원유로 한정한다)
# 41. 석탄과 석탄으로 제조한 연탄ㆍ조개탄(ovoid)과 이와 유사한 고체 연료
# 42. 면[카드(card)하지도 코움(comb)하지도 않은 것으로 한정한다]
#
# 🔸 클러스터 1 체인 순서 (총 2개)
#  1. 유아용 의류와 그 부속품(메리야스 편물이나 뜨개질 편물로 한정한다)
#  2. 유아용 의류와 그 부속품(메리야스 편물이나 뜨개질 편물로 한정한다)
#
# 🔸 클러스터 2 체인 순서 (총 2개)
#  1. 대두유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#  2. 알루미늄광과 그 정광(精鑛)
#
# 🔸 클러스터 3 체인 순서 (총 2개)
#  1. 남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cape)ㆍ클록(cloak)ㆍ아노락(anorak)(스키재킷을 포함한다)ㆍ윈드치터(wind-cheater)ㆍ윈드재킷(wind-jacket)과 이와 유사한 의류(메리야스 편물과 뜨개질 편물로 한정하며, 제6103호의 것은 제외한다)
#  2. 남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cape)ㆍ클록(cloak)ㆍ아노락(anorak)(스키재킷을 포함한다)ㆍ윈드치터(wind-cheater)ㆍ윈드재킷(wind-jacket)과 이와 유사한 의류(제6203호의 것은 제외한다)
#
# 🔸 클러스터 4 체인 순서 (총 9개)
#  1. 그 밖의 무기산과 무기 비(非)금속 산화물
#  2. 철이나 비합금강의 형강(形鋼)
#  3. 그 밖의 호흡용 기기와 가스마스크(기계적인 부분품과 교환용 필터를 모두 갖추지 않은 보호용 마스크는 제외한다)
#  4. 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이, 셀룰로오스워딩ㆍ셀룰로오스섬유의 웹(web)[주름지거나(creped) 구겨진(crinkled) 것, 올록볼록한(embossed) 것, 구멍을 뚫은(perforated) 것, 착색한 것, 표면장식한 것, 인쇄한 것인지에 상관없으며 롤 모양이나 시트(sheet) 모양으로 한정한다]
#  5. 철이나 비합금강의 봉[열간(熱間)압연한 것으로서 불규칙적으로 감은 코일 모양인 것으로 한정한다]
#  6. 베릴륨ㆍ크로뮴ㆍ하프늄ㆍ레늄ㆍ탈륨ㆍ카드뮴ㆍ게르마늄ㆍ바나듐ㆍ갈륨ㆍ인듐ㆍ니오븀(컬럼븀)과 이것으로 만든 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  7. 니켈의 괴(塊)
#  8. 석유가스와 그 밖의 가스 상태의 탄화수소
#  9. 망간과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#
# 🔸 클러스터 5 체인 순서 (총 3개)
#  1. 자주식(自走式) 철도용이나 궤도용 객차와 화차(제8604호의 것은 제외한다)
#  2. 철강으로 만든 구조물(제9406호의 조립식 건축물은 제외한다)과 구조물의 부분품[예: 다리와 교량ㆍ수문ㆍ탑ㆍ격자주(格子柱)ㆍ지붕ㆍ지붕틀ㆍ문과 창 및 이들의 틀과 문지방ㆍ셔터ㆍ난간ㆍ기둥], 구조물용으로 가공한 철강으로 만든 판ㆍ대ㆍ봉ㆍ형재(形材)ㆍ관(管)과 이와 유사한 것
#  3. 인조필라멘트사(재봉사는 제외하며, 소매용으로 한정한다)
#
# 🔸 클러스터 6 체인 순서 (총 3개)
#  1. 그 밖의 차량[압축점화식 피스톤 내연기관(디젤이나 세미디젤)과 추진용 모터로서의 전동기를 둘 다 갖춘 것으로서, 외부 전원에 플러그를 꽂아 충전할 수 있는 방식의 것은 제외한다]
#  2. 백금(가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#  3. 발전세트와 회전변환기
#
# 🔸 클러스터 7 체인 순서 (총 2개)
#  1. 그 밖의 항공기(예: 헬리콥터ㆍ비행기)(제8806호의 무인기를 제외한다), 우주선(인공위성을 포함한다)ㆍ서보비틀(suborbital) 발사체ㆍ우주선 발사체
#  2. 그 밖의 항공기(예: 헬리콥터ㆍ비행기)(제8806호의 무인기를 제외한다), 우주선(인공위성을 포함한다)ㆍ서보비틀(suborbital) 발사체ㆍ우주선 발사체
#
# 🔸 클러스터 8 체인 순서 (총 2개)
#  1. 농업용ㆍ원예용ㆍ임업용 기계(토양 정리용이나 경작용으로 한정한다)와 잔디용이나 운동장용 롤러
#  2. 농업용ㆍ원예용ㆍ임업용 기계(토양 정리용이나 경작용으로 한정한다)와 잔디용이나 운동장용 롤러
#
# 🔸 클러스터 9 체인 순서 (총 8개)
#  1. 구리광과 그 정광(精鑛)
#  2. 제재목[길이의 방향으로 쪼갠 것, 평삭(平削)한 것, 회전식으로 절단한 것으로서 두께가 6밀리미터를 초과하는 것으로 한정하며, 대패질ㆍ연마ㆍ엔드-조인트한(end-jointed) 것인지에 상관없다]
#  3. 전기기계식의 가정용 기기(전동기를 갖춘 것으로 한정하며, 제8508호의 진공청소기는 제외한다)
#  4. 대두(부수었는지에 상관없다)
#  5. 그 밖의 차량(불꽃점화식 피스톤 내연기관과 추진용 모터로서의 전동기를 둘 다 갖춘 것으로서, 외부 전원에 플러그를 꽂아 충전할 수 있는 방식의 것으로 한정한다)
#  6. 금(백금을 도금한 금을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#  7. 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 한정하며, 표면을 도포하거나 침투시킨 것은 제외하고, 내면을 보강했는지에 상관없다]
#  8. 지르코늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#
# 🔸 클러스터 10 체인 순서 (총 18개)
#  1. 전기식의 즉시식ㆍ저장식 물가열기와 투입식 가열기, 난방기기와 토양가열기, 전기가열식 이용기기[예: 헤어드라이어ㆍ헤어컬러(hair curler)ㆍ컬링통히터(curling tong heater)], 손 건조기, 전기다리미, 그 밖의 가정용 전열기기, 전열용 저항체(제8545호의 것은 제외한다)
#  2. 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)
#  3. 정형외과용 기기(목발ㆍ외과용 벨트와 탈장대를 포함한다), 골절 치료용 부목과 그 밖의 골절 치료구, 인공 인체 부분, 보청기, 결함ㆍ장애를 보정하기 위하여 착용하거나 휴대하거나 인체에 삽입하는 그 밖의 기기
#  4. 원목[껍질ㆍ변재(邊材)를 벗긴 것인지 또는 거칠게 각을 뜬 것인지에 상관없다]
#  5. 옥수수
#  6. 엑스선이나 알파선ㆍ베타선ㆍ감마선ㆍ그 밖의 전리선을 사용하는 기기(내과용ㆍ외과용ㆍ치과용ㆍ수의과용인지에 상관없으며 방사선 사진용이나 방사선 치료용 기기ㆍ엑스선관과 그 밖의 엑스선 발생기ㆍ고압 발생기ㆍ조절반ㆍ스크린ㆍ검사용이나 치료용 테이블ㆍ의자와 이와 유사한 물품을 포함한다)
#  7. 전화기(셀룰러 통신망용이나 그 밖의 무선통신망용의 스마트폰과 그 밖의 전화기를 포함한다)와 음성ㆍ영상이나 그 밖의 자료의 송신용ㆍ수신용 그 밖의 기기(근거리 통신망이나 원거리 통신망과 같은 유선ㆍ무선 통신망에서 통신하기 위한 기기를 포함하며, 제8443호ㆍ제8525호ㆍ제8527호ㆍ제8528호의 송신용ㆍ수신용 기기는 제외한다)
#  8. 전자공업에 사용하기 위하여 도프처리된(doped) 화학원소(디스크ㆍ웨이퍼 모양이나 이와 유사한 모양으로 한정한다), 전자공업에 사용하기 위하여 도프처리된(doped) 화학화합물
#  9. 은(금이나 백금을 도금한 은을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
# 10. 기계요법용 기기, 마사지용 기기, 심리학적 적성검사용 기기, 오존 흡입기ㆍ산소 흡입기ㆍ에어로졸 치료기ㆍ인공호흡기나 그 밖의 치료용 호흡기기
# 11. 실린더용량이 1,500시시 초과 3,000시시 이하인 것
# 12. 실린더용량이 3,000시시를 초과하는 것
# 13. 이 류에 따로 분류되지 않은 기계류(고유의 기능을 가진 것으로 한정한다)
# 14. 전기식(전기발열에 따른 가스식을 포함한다)ㆍ레이저나 그 밖의 광선식ㆍ광자빔식ㆍ초음파식ㆍ전자빔식ㆍ자기펄스(magnetic pulse)식ㆍ플라즈마 아크(plasma arc)식 납땜용ㆍ땜질용이나 용접용 기기(절단기능이 있는지에 상관없다), 금속이나 서멧(cermet)의 가열분사용 전기식 기기
# 15. 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric loss)식을 포함한다]과 그 밖의 공업용이나 실험실용의 전자유도식이나 유전손실(dielectric loss)식 가열기
# 16. 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, 제8512호의 조명기구는 제외한다)
# 17. 천연고무ㆍ발라타(balata)ㆍ구타페르카(gutta-percha)ㆍ구아율(guayule)ㆍ치클(chicle)과 이와 유사한 천연 검(gum)[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다]
# 18. 면도기ㆍ이발기ㆍ모발제거기[전동기를 갖춘 것으로 한정한다]
#
# 🔸 클러스터 11 체인 순서 (총 2개)
#  1. 팜유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#  2. 팜유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#
# 🔸 클러스터 12 체인 순서 (총 2개)
#  1. 안티모니와 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  2. 안티모니와 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]

# %%
plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_pca2[:, 0], X_pca2[:, 1], c=y_pred2, cmap='tab20', s=50)
plt.title("PCA of Clustered Data", fontsize=16)
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.colorbar(scatter, label='Cluster ID')
plt.grid(True)
plt.show()

# %%
from sklearn.cluster import SpectralClustering

model = SpectralClustering(n_clusters=9, affinity='nearest_neighbors')
labels2 = model.fit_predict(feature_tensor)

# %%
# 'pivot_df'의 첫 번째 열이 '품목명'이라고 가정
품목명_series = pivot_df.iloc[:, 1]

# 클러스터 결과를 붙이기
result_df = pd.DataFrame({
    '품목명': 품목명_series,
    '클러스터': labels2
})

# 클러스터별 품목 리스트 출력
for cluster_id, group in result_df.groupby('클러스터'):
    print(f"\n🔹 클러스터 {cluster_id} (총 {len(group)}개 품목)")
    for name in group['품목명']:
        print(f" - {name}")
# Out:
# 🔹 클러스터 0 (총 8개 품목)
#  - 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric loss)식을 포함한다]과 그 밖의 공업용이나 실험실용의 전자유도식이나 유전손실(dielectric loss)식 가열기
#  - 그 밖의 항공기(예: 헬리콥터ㆍ비행기)(제8806호의 무인기를 제외한다), 우주선(인공위성을 포함한다)ㆍ서보비틀(suborbital) 발사체ㆍ우주선 발사체
#  - 기계요법용 기기, 마사지용 기기, 심리학적 적성검사용 기기, 오존 흡입기ㆍ산소 흡입기ㆍ에어로졸 치료기ㆍ인공호흡기나 그 밖의 치료용 호흡기기
#  - 실린더용량이 1,500시시 초과 3,000시시 이하인 것
#  - 알루미늄광과 그 정광(精鑛)
#  - 은(금이나 백금을 도금한 은을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#  - 이 류에 따로 분류되지 않은 기계류(고유의 기능을 가진 것으로 한정한다)
#  - 전기식(전기발열에 따른 가스식을 포함한다)ㆍ레이저나 그 밖의 광선식ㆍ광자빔식ㆍ초음파식ㆍ전자빔식ㆍ자기펄스(magnetic pulse)식ㆍ플라즈마 아크(plasma arc)식 납땜용ㆍ땜질용이나 용접용 기기(절단기능이 있는지에 상관없다), 금속이나 서멧(cermet)의 가열분사용 전기식 기기
#
# 🔹 클러스터 1 (총 6개 품목)
#  - 구리광과 그 정광(精鑛)
#  - 남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cape)ㆍ클록(cloak)ㆍ아노락(anorak)(스키재킷을 포함한다)ㆍ윈드치터(wind-cheater)ㆍ윈드재킷(wind-jacket)과 이와 유사한 의류(메리야스 편물과 뜨개질 편물로 한정하며, 제6103호의 것은 제외한다)
#  - 남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cape)ㆍ클록(cloak)ㆍ아노락(anorak)(스키재킷을 포함한다)ㆍ윈드치터(wind-cheater)ㆍ윈드재킷(wind-jacket)과 이와 유사한 의류(제6203호의 것은 제외한다)
#  - 부분품(제8501호나 제8502호의 기계에 전용되거나 주로 사용되는 것으로 한정한다)
#  - 유아용 의류와 그 부속품(메리야스 편물이나 뜨개질 편물로 한정한다)
#  - 제재목[길이의 방향으로 쪼갠 것, 평삭(平削)한 것, 회전식으로 절단한 것으로서 두께가 6밀리미터를 초과하는 것으로 한정하며, 대패질ㆍ연마ㆍ엔드-조인트한(end-jointed) 것인지에 상관없다]
#
# 🔹 클러스터 2 (총 14개 품목)
#  - 도포하지 않은 종이와 판지(필기용, 인쇄용, 그 밖의 그래픽용으로 한정한다), 구멍을 뚫지 않은 펀치카드와 펀치테이프지[제4801호와 제4803호의 것은 제외하며, 크기와는 관계 없이 롤 모양이나 직사각형(정사각형을 포함한다) 시트(sheet) 모양으로 한정한다], 수제(手製) 종이와 판지
#  - 따로 분류되지 않은 조제 식료품
#  - 밀과 메슬린(meslin)
#  - 석유와 역청유(瀝靑油)(원유로 한정한다)
#  - 의약품[혼합한 것인지에 상관없으며 치료용이나 예방용의 것으로서 일정한 투여량으로 한 것(피부 투여의 형식을 취한 것을 포함한다)과 소매용 모양이나 포장을 한 것으로 한정하며, 제3002호ㆍ제3005호ㆍ제3006호의 물품은 제외한다]
#  - 지르코늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 철이나 비합금강의 그 밖의 봉[단조(鍛造)ㆍ열간(熱間)압연ㆍ열간인발(熱間引拔)ㆍ열간(熱間)압출보다 더 가공하지 않은 것으로 한정하고, 압연 후 꼬임가공된 것을 포함한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 미만인 것으로서 클래드(clad)ㆍ도금ㆍ도포한 것으로 한정한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 열간(熱間)압연한 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  - 축전지(격리판을 포함하며, 직사각형이나 정사각형인지에 상관없다)
#  - 카본지, 셀프복사지, 그 밖의 복사지나 전사지[등사원지나 오프셋 플레이트(offset plate)로 사용하는 도포지와 침투지를 포함하고, 인쇄한 것인지에 상관없으며 롤 모양이나 시트(sheet) 모양으로 한정한다]
#  - 티타늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 합성모노필라멘트(67데시텍스 이상인 것으로서 횡단면의 치수가 1밀리미터 이하인 것으로 한정한다), 방직용 합성섬유재료의 스트립(strip)이나 이와 유사한 것[예: 인조스트로(straw)](시폭이 5밀리미터 이하인 것으로 한정한다)
#  - 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine paper)와 그 밖의 투명 광택지나 반투명 광택지[롤 모양이나 시트(sheet) 모양으로 한정한다]
#
# 🔹 클러스터 3 (총 8개 품목)
#  - 그 밖의 무기산과 무기 비(非)금속 산화물
#  - 그 밖의 호흡용 기기와 가스마스크(기계적인 부분품과 교환용 필터를 모두 갖추지 않은 보호용 마스크는 제외한다)
#  - 농업용ㆍ원예용ㆍ임업용 기계(토양 정리용이나 경작용으로 한정한다)와 잔디용이나 운동장용 롤러
#  - 니켈의 괴(塊)
#  - 베릴륨ㆍ크로뮴ㆍ하프늄ㆍ레늄ㆍ탈륨ㆍ카드뮴ㆍ게르마늄ㆍ바나듐ㆍ갈륨ㆍ인듐ㆍ니오븀(컬럼븀)과 이것으로 만든 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 철이나 비합금강의 봉[열간(熱間)압연한 것으로서 불규칙적으로 감은 코일 모양인 것으로 한정한다]
#  - 철이나 비합금강의 형강(形鋼)
#  - 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이, 셀룰로오스워딩ㆍ셀룰로오스섬유의 웹(web)[주름지거나(creped) 구겨진(crinkled) 것, 올록볼록한(embossed) 것, 구멍을 뚫은(perforated) 것, 착색한 것, 표면장식한 것, 인쇄한 것인지에 상관없으며 롤 모양이나 시트(sheet) 모양으로 한정한다]
#
# 🔹 클러스터 4 (총 7개 품목)
#  - 석탄과 석탄으로 제조한 연탄ㆍ조개탄(ovoid)과 이와 유사한 고체 연료
#  - 에틸렌의 중합체[일차제품(primary form)으로 한정한다]
#  - 철광과 그 정광(精鑛)[배소(焙燒)한 황화철광을 포함한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 냉간압연(냉간환원)한 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 클래드(clad)ㆍ도금ㆍ도포한 것으로 한정한다]
#  - 팜유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#  - 합성고무와 기름에서 제조한 팩티스(factice)[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다], 제4001호의 물품과 제4002호의 물품과의 혼합물[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다]
#
# 🔹 클러스터 5 (총 15개 품목)
#  - 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 한정하며, 표면을 도포하거나 침투시킨 것은 제외하고, 내면을 보강했는지에 상관없다]
#  - 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polarizing material)로 만든 판, 각종 재료로 만든 렌즈(콘택트렌즈를 포함한다)ㆍ프리즘ㆍ반사경과 그 밖의 광학소자로서 장착되지 않은 것(광학적으로 가공하지 않은 유리로 만든 광학소자는 제외한다)
#  - 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 이 류의 주 제3호의 것 이상의 가공을 하지 않은 것으로 한정한다]
#  - 망간과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 면[카드(card)하지도 코움(comb)하지도 않은 것으로 한정한다]
#  - 물결 모양으로 하거나(corrugated)(평면지가 붙은 것인지에 상관없다) 주름지거나(creped) 구겨지거나(crinkled) 올록볼록하거나(embossed) 구멍을 뚫은(perforated) 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 제4803호의 것은 제외한다]
#  - 실험실용ㆍ화학용이나 그 밖의 공업용 도자제품, 농업용 도자제 통과 이와 유사한 용기, 물품의 수송용ㆍ포장용으로 사용하는 도자제의 항아리ㆍ단지와 이와 유사한 제품
#  - 알루미늄의 괴(塊)
#  - 전기식 조명용이나 신호용 기구(제8539호의 물품은 제외한다)ㆍ윈드스크린와이퍼(windscreen wiper)ㆍ제상기(defroster)ㆍ제무기(demister)(자전거용이나 자동차용으로 한정한다)
#  - 종이, 판지, 셀룰로오스워딩, 셀룰로오스섬유의 웹(web)[크기와는 관계 없이 롤 모양이나 직사각형(정사각형을 포함한다)의 시트(sheet) 모양으로서 도포ㆍ침투ㆍ피복ㆍ표면착색ㆍ표면장식ㆍ인쇄한 것으로 한정하며, 제4803호ㆍ제4809호ㆍ제4810호에 열거한 것은 제외한다]
#  - 철이나 비합금강의 그 밖의 봉
#  - 철이나 비합금강의 평판압연제품[폭이 600밀리미터 미만인 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  - 텔레비전 수신기기를 갖추지 않은 모니터와 프로젝터, 텔레비전 수신용 기기(라디오 방송용 수신기기ㆍ음성이나 영상의 기록용 기기나 재생용 기기를 결합한 것인지에 상관없다)
#  - 한 면이나 양면을 도포한 종이와 판지[결합재가 있는지에 상관없으며 고령토(kaolin)[차이나 클레이(China clay)]나 그 밖의 무기물질을 도포한 것(그 밖의 다른 물질을 도포한 것은 제외한다)으로서 표면착색ㆍ표면장식ㆍ인쇄하였는지에 상관없으며 크기와는 관계없이 롤 모양이나 직사각형(정사각형을 포함한다)의 시트(sheet) 모양으로 한정한다]
#  - 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다)
#
# 🔹 클러스터 6 (총 12개 품목)
#  - 그 밖의 차량(추진용 전동기만을 갖춘 것)
#  - 내과용ㆍ외과용ㆍ치과용ㆍ수의과용 기기[신티그래픽(scintigraphic)식 진단기기ㆍ그 밖의 전기식 의료기기와 시력 검사기기를 포함한다]
#  - 반도체 디바이스(예: 다이오드ㆍ트랜지스터ㆍ반도체 기반 트랜스듀서), 감광성 반도체 디바이스(광전지는 모듈에 조립되었거나 패널로 구성되었는지 여부와 관계없이 포함한다), 발광다이오드[(엘이디), 다른 발광다이오드와 결합되었는지 여부과 관계없이 포함한다], 장착된 압전기 결정소자
#  - 불꽃점화식이나 압축점화식 내연기관의 점화용ㆍ시동용 전기기기(예: 점화용 자석발전기ㆍ자석발전기ㆍ점화코일ㆍ점화플러그ㆍ예열플러그ㆍ시동전동기), 내연기관에 부속되는 발전기(예: 직류발전기ㆍ교류발전기)와 개폐기
#  - 석유가스와 그 밖의 가스 상태의 탄화수소
#  - 엑스선이나 알파선ㆍ베타선ㆍ감마선ㆍ그 밖의 전리선을 사용하는 기기(내과용ㆍ외과용ㆍ치과용ㆍ수의과용인지에 상관없으며 방사선 사진용이나 방사선 치료용 기기ㆍ엑스선관과 그 밖의 엑스선 발생기ㆍ고압 발생기ㆍ조절반ㆍ스크린ㆍ검사용이나 치료용 테이블ㆍ의자와 이와 유사한 물품을 포함한다)
#  - 옥수수
#  - 재생ㆍ반(半)합성 필라멘트사[재봉사와 소매용은 제외하며, 67데시텍스 미만인 재생ㆍ반(半)합성 모노필라멘트를 포함한다]
#  - 전동기와 발전기(발전세트는 제외한다)
#  - 전자공업에 사용하기 위하여 도프처리된(doped) 화학원소(디스크ㆍ웨이퍼 모양이나 이와 유사한 모양으로 한정한다), 전자공업에 사용하기 위하여 도프처리된(doped) 화학화합물
#  - 전화기(셀룰러 통신망용이나 그 밖의 무선통신망용의 스마트폰과 그 밖의 전화기를 포함한다)와 음성ㆍ영상이나 그 밖의 자료의 송신용ㆍ수신용 그 밖의 기기(근거리 통신망이나 원거리 통신망과 같은 유선ㆍ무선 통신망에서 통신하기 위한 기기를 포함하며, 제8443호ㆍ제8525호ㆍ제8527호ㆍ제8528호의 송신용ㆍ수신용 기기는 제외한다)
#  - 천연고무ㆍ발라타(balata)ㆍ구타페르카(gutta-percha)ㆍ구아율(guayule)ㆍ치클(chicle)과 이와 유사한 천연 검(gum)[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다]
#
# 🔹 클러스터 7 (총 14개 품목)
#  - 그 밖의 차량[압축점화식 피스톤 내연기관(디젤이나 세미디젤)과 추진용 모터로서의 전동기를 둘 다 갖춘 것으로서, 외부 전원에 플러그를 꽂아 충전할 수 있는 방식의 것은 제외한다]
#  - 대두유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#  - 발전세트와 회전변환기
#  - 백금(가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#  - 실린더용량이 3,000시시를 초과하는 것
#  - 안티모니와 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 원목[껍질ㆍ변재(邊材)를 벗긴 것인지 또는 거칠게 각을 뜬 것인지에 상관없다]
#  - 인조필라멘트사(재봉사는 제외하며, 소매용으로 한정한다)
#  - 자주식(自走式) 철도용이나 궤도용 객차와 화차(제8604호의 것은 제외한다)
#  - 전기식의 즉시식ㆍ저장식 물가열기와 투입식 가열기, 난방기기와 토양가열기, 전기가열식 이용기기[예: 헤어드라이어ㆍ헤어컬러(hair curler)ㆍ컬링통히터(curling tong heater)], 손 건조기, 전기다리미, 그 밖의 가정용 전열기기, 전열용 저항체(제8545호의 것은 제외한다)
#  - 정형외과용 기기(목발ㆍ외과용 벨트와 탈장대를 포함한다), 골절 치료용 부목과 그 밖의 골절 치료구, 인공 인체 부분, 보청기, 결함ㆍ장애를 보정하기 위하여 착용하거나 휴대하거나 인체에 삽입하는 그 밖의 기기
#  - 철강으로 만든 구조물(제9406호의 조립식 건축물은 제외한다)과 구조물의 부분품[예: 다리와 교량ㆍ수문ㆍ탑ㆍ격자주(格子柱)ㆍ지붕ㆍ지붕틀ㆍ문과 창 및 이들의 틀과 문지방ㆍ셔터ㆍ난간ㆍ기둥], 구조물용으로 가공한 철강으로 만든 판ㆍ대ㆍ봉ㆍ형재(形材)ㆍ관(管)과 이와 유사한 것
#  - 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)
#  - 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, 제8512호의 조명기구는 제외한다)
#
# 🔹 클러스터 8 (총 8개 품목)
#  - 그 밖의 차량(불꽃점화식 피스톤 내연기관과 추진용 모터로서의 전동기를 둘 다 갖춘 것으로서, 외부 전원에 플러그를 꽂아 충전할 수 있는 방식의 것으로 한정한다)
#  - 금(백금을 도금한 금을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#  - 대두(부수었는지에 상관없다)
#  - 도포하지 않은 크라프트지와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 제4802호나 제4803호의 것은 제외한다]
#  - 면도기ㆍ이발기ㆍ모발제거기[전동기를 갖춘 것으로 한정한다]
#  - 서멧(cermet)과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  - 전기기계식의 가정용 기기(전동기를 갖춘 것으로 한정하며, 제8508호의 진공청소기는 제외한다)
#  - 철도용이나 궤도용 기관차나 차량의 부분품

# %%
from scipy.spatial.distance import cdist
import numpy as np

# 품목명과 feature_tensor를 담은 전체 result_df
result_df = pd.DataFrame({
    '품목명': pivot_df.iloc[:, 1].values,
    '클러스터': labels2
})

# feature_tensor는 품목명 순서와 같은 순서라고 가정
result_df['feature'] = list(feature_tensor)

# 체인 순서 함수 정의
def build_chain_order(cluster_features, cluster_names):
    n = len(cluster_features)
    distances = cdist(cluster_features, cluster_features, metric='euclidean')
    np.fill_diagonal(distances, np.inf)  # 자기 자신은 제외

    visited = [False] * n
    chain = []

    # 시작은 가장 가까운 쌍 중 하나
    i, j = np.unravel_index(np.argmin(distances), distances.shape)
    chain.extend([i, j])
    visited[i] = visited[j] = True

    while len(chain) < n:
        last = chain[-1]
        dists = distances[last]
        for idx in np.argsort(dists):
            if not visited[idx]:
                chain.append(idx)
                visited[idx] = True
                break
    return [cluster_names[i] for i in chain]

# 클러스터별 체인 출력
for cluster_id, group in result_df.groupby('클러스터'):
    cluster_names = group['품목명'].tolist()
    cluster_features = np.stack(group['feature'].values)

    chain_order = build_chain_order(cluster_features, cluster_names)

    print(f"\n🔸 클러스터 {cluster_id} 체인 순서 (총 {len(chain_order)}개)")
    for i, name in enumerate(chain_order):
        print(f"{i+1:2d}. {name}")
# Out:
# 🔸 클러스터 0 체인 순서 (총 8개)
#  1. 기계요법용 기기, 마사지용 기기, 심리학적 적성검사용 기기, 오존 흡입기ㆍ산소 흡입기ㆍ에어로졸 치료기ㆍ인공호흡기나 그 밖의 치료용 호흡기기
#  2. 은(금이나 백금을 도금한 은을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#  3. 실린더용량이 1,500시시 초과 3,000시시 이하인 것
#  4. 이 류에 따로 분류되지 않은 기계류(고유의 기능을 가진 것으로 한정한다)
#  5. 전기식(전기발열에 따른 가스식을 포함한다)ㆍ레이저나 그 밖의 광선식ㆍ광자빔식ㆍ초음파식ㆍ전자빔식ㆍ자기펄스(magnetic pulse)식ㆍ플라즈마 아크(plasma arc)식 납땜용ㆍ땜질용이나 용접용 기기(절단기능이 있는지에 상관없다), 금속이나 서멧(cermet)의 가열분사용 전기식 기기
#  6. 공업용이나 실험실용 전기식 노(爐)와 오븐[전자유도식이나 유전손실(dielectric loss)식을 포함한다]과 그 밖의 공업용이나 실험실용의 전자유도식이나 유전손실(dielectric loss)식 가열기
#  7. 알루미늄광과 그 정광(精鑛)
#  8. 그 밖의 항공기(예: 헬리콥터ㆍ비행기)(제8806호의 무인기를 제외한다), 우주선(인공위성을 포함한다)ㆍ서보비틀(suborbital) 발사체ㆍ우주선 발사체
#
# 🔸 클러스터 1 체인 순서 (총 6개)
#  1. 구리광과 그 정광(精鑛)
#  2. 제재목[길이의 방향으로 쪼갠 것, 평삭(平削)한 것, 회전식으로 절단한 것으로서 두께가 6밀리미터를 초과하는 것으로 한정하며, 대패질ㆍ연마ㆍ엔드-조인트한(end-jointed) 것인지에 상관없다]
#  3. 부분품(제8501호나 제8502호의 기계에 전용되거나 주로 사용되는 것으로 한정한다)
#  4. 유아용 의류와 그 부속품(메리야스 편물이나 뜨개질 편물로 한정한다)
#  5. 남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cape)ㆍ클록(cloak)ㆍ아노락(anorak)(스키재킷을 포함한다)ㆍ윈드치터(wind-cheater)ㆍ윈드재킷(wind-jacket)과 이와 유사한 의류(메리야스 편물과 뜨개질 편물로 한정하며, 제6103호의 것은 제외한다)
#  6. 남성용이나 소년용 오버코트(overcoat)ㆍ카코트(car-coat)ㆍ케이프(cape)ㆍ클록(cloak)ㆍ아노락(anorak)(스키재킷을 포함한다)ㆍ윈드치터(wind-cheater)ㆍ윈드재킷(wind-jacket)과 이와 유사한 의류(제6203호의 것은 제외한다)
#
# 🔸 클러스터 2 체인 순서 (총 14개)
#  1. 도포하지 않은 종이와 판지(필기용, 인쇄용, 그 밖의 그래픽용으로 한정한다), 구멍을 뚫지 않은 펀치카드와 펀치테이프지[제4801호와 제4803호의 것은 제외하며, 크기와는 관계 없이 롤 모양이나 직사각형(정사각형을 포함한다) 시트(sheet) 모양으로 한정한다], 수제(手製) 종이와 판지
#  2. 티타늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  3. 합성모노필라멘트(67데시텍스 이상인 것으로서 횡단면의 치수가 1밀리미터 이하인 것으로 한정한다), 방직용 합성섬유재료의 스트립(strip)이나 이와 유사한 것[예: 인조스트로(straw)](시폭이 5밀리미터 이하인 것으로 한정한다)
#  4. 따로 분류되지 않은 조제 식료품
#  5. 황산지ㆍ내지지(耐脂紙)ㆍ트레이싱지(tracing paper)ㆍ글라신지(glassine paper)와 그 밖의 투명 광택지나 반투명 광택지[롤 모양이나 시트(sheet) 모양으로 한정한다]
#  6. 밀과 메슬린(meslin)
#  7. 철이나 비합금강의 그 밖의 봉[단조(鍛造)ㆍ열간(熱間)압연ㆍ열간인발(熱間引拔)ㆍ열간(熱間)압출보다 더 가공하지 않은 것으로 한정하고, 압연 후 꼬임가공된 것을 포함한다]
#  8. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 열간(熱間)압연한 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  9. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 미만인 것으로서 클래드(clad)ㆍ도금ㆍ도포한 것으로 한정한다]
# 10. 카본지, 셀프복사지, 그 밖의 복사지나 전사지[등사원지나 오프셋 플레이트(offset plate)로 사용하는 도포지와 침투지를 포함하고, 인쇄한 것인지에 상관없으며 롤 모양이나 시트(sheet) 모양으로 한정한다]
# 11. 축전지(격리판을 포함하며, 직사각형이나 정사각형인지에 상관없다)
# 12. 석유와 역청유(瀝靑油)(원유로 한정한다)
# 13. 의약품[혼합한 것인지에 상관없으며 치료용이나 예방용의 것으로서 일정한 투여량으로 한 것(피부 투여의 형식을 취한 것을 포함한다)과 소매용 모양이나 포장을 한 것으로 한정하며, 제3002호ㆍ제3005호ㆍ제3006호의 물품은 제외한다]
# 14. 지르코늄과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#
# 🔸 클러스터 3 체인 순서 (총 8개)
#  1. 그 밖의 무기산과 무기 비(非)금속 산화물
#  2. 철이나 비합금강의 형강(形鋼)
#  3. 그 밖의 호흡용 기기와 가스마스크(기계적인 부분품과 교환용 필터를 모두 갖추지 않은 보호용 마스크는 제외한다)
#  4. 화장지ㆍ안면용 티슈용 원지, 타월ㆍ냅킨용 원지와 이와 유사한 가정용이나 위생용 종이, 셀룰로오스워딩ㆍ셀룰로오스섬유의 웹(web)[주름지거나(creped) 구겨진(crinkled) 것, 올록볼록한(embossed) 것, 구멍을 뚫은(perforated) 것, 착색한 것, 표면장식한 것, 인쇄한 것인지에 상관없으며 롤 모양이나 시트(sheet) 모양으로 한정한다]
#  5. 철이나 비합금강의 봉[열간(熱間)압연한 것으로서 불규칙적으로 감은 코일 모양인 것으로 한정한다]
#  6. 베릴륨ㆍ크로뮴ㆍ하프늄ㆍ레늄ㆍ탈륨ㆍ카드뮴ㆍ게르마늄ㆍ바나듐ㆍ갈륨ㆍ인듐ㆍ니오븀(컬럼븀)과 이것으로 만든 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  7. 니켈의 괴(塊)
#  8. 농업용ㆍ원예용ㆍ임업용 기계(토양 정리용이나 경작용으로 한정한다)와 잔디용이나 운동장용 롤러
#
# 🔸 클러스터 4 체인 순서 (총 7개)
#  1. 철광과 그 정광(精鑛)[배소(焙燒)한 황화철광을 포함한다]
#  2. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 클래드(clad)ㆍ도금ㆍ도포한 것으로 한정한다]
#  3. 합성고무와 기름에서 제조한 팩티스(factice)[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다], 제4001호의 물품과 제4002호의 물품과의 혼합물[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다]
#  4. 에틸렌의 중합체[일차제품(primary form)으로 한정한다]
#  5. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 이상인 것으로서 냉간압연(냉간환원)한 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  6. 석탄과 석탄으로 제조한 연탄ㆍ조개탄(ovoid)과 이와 유사한 고체 연료
#  7. 팜유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#
# 🔸 클러스터 5 체인 순서 (총 15개)
#  1. 철이나 비합금강의 평판압연제품[폭이 600밀리미터 미만인 것으로 한정하고, 클래드(clad)ㆍ도금ㆍ도포한 것은 제외한다]
#  2. 합성필라멘트사(재봉사와 소매용은 제외하며, 67데시텍스 미만인 합성모노필라멘트를 포함한다)
#  3. 알루미늄의 괴(塊)
#  4. 광섬유와 광섬유 다발, 제8544호의 것 외의 광섬유 케이블, 편광재료(polarizing material)로 만든 판, 각종 재료로 만든 렌즈(콘택트렌즈를 포함한다)ㆍ프리즘ㆍ반사경과 그 밖의 광학소자로서 장착되지 않은 것(광학적으로 가공하지 않은 유리로 만든 광학소자는 제외한다)
#  5. 텔레비전 수신기기를 갖추지 않은 모니터와 프로젝터, 텔레비전 수신용 기기(라디오 방송용 수신기기ㆍ음성이나 영상의 기록용 기기나 재생용 기기를 결합한 것인지에 상관없다)
#  6. 실험실용ㆍ화학용이나 그 밖의 공업용 도자제품, 농업용 도자제 통과 이와 유사한 용기, 물품의 수송용ㆍ포장용으로 사용하는 도자제의 항아리ㆍ단지와 이와 유사한 제품
#  7. 한 면이나 양면을 도포한 종이와 판지[결합재가 있는지에 상관없으며 고령토(kaolin)[차이나 클레이(China clay)]나 그 밖의 무기물질을 도포한 것(그 밖의 다른 물질을 도포한 것은 제외한다)으로서 표면착색ㆍ표면장식ㆍ인쇄하였는지에 상관없으며 크기와는 관계없이 롤 모양이나 직사각형(정사각형을 포함한다)의 시트(sheet) 모양으로 한정한다]
#  8. 전기식 조명용이나 신호용 기구(제8539호의 물품은 제외한다)ㆍ윈드스크린와이퍼(windscreen wiper)ㆍ제상기(defroster)ㆍ제무기(demister)(자전거용이나 자동차용으로 한정한다)
#  9. 종이, 판지, 셀룰로오스워딩, 셀룰로오스섬유의 웹(web)[크기와는 관계 없이 롤 모양이나 직사각형(정사각형을 포함한다)의 시트(sheet) 모양으로서 도포ㆍ침투ㆍ피복ㆍ표면착색ㆍ표면장식ㆍ인쇄한 것으로 한정하며, 제4803호ㆍ제4809호ㆍ제4810호에 열거한 것은 제외한다]
# 10. 철이나 비합금강의 그 밖의 봉
# 11. 그 밖의 도포하지 않은 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 이 류의 주 제3호의 것 이상의 가공을 하지 않은 것으로 한정한다]
# 12. 겹붙인 종이와 판지[접착제로 겹붙인 것으로서 롤 모양이나 시트(sheet) 모양으로 한정하며, 표면을 도포하거나 침투시킨 것은 제외하고, 내면을 보강했는지에 상관없다]
# 13. 물결 모양으로 하거나(corrugated)(평면지가 붙은 것인지에 상관없다) 주름지거나(creped) 구겨지거나(crinkled) 올록볼록하거나(embossed) 구멍을 뚫은(perforated) 종이와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 제4803호의 것은 제외한다]
# 14. 망간과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
# 15. 면[카드(card)하지도 코움(comb)하지도 않은 것으로 한정한다]
#
# 🔸 클러스터 6 체인 순서 (총 12개)
#  1. 내과용ㆍ외과용ㆍ치과용ㆍ수의과용 기기[신티그래픽(scintigraphic)식 진단기기ㆍ그 밖의 전기식 의료기기와 시력 검사기기를 포함한다]
#  2. 재생ㆍ반(半)합성 필라멘트사[재봉사와 소매용은 제외하며, 67데시텍스 미만인 재생ㆍ반(半)합성 모노필라멘트를 포함한다]
#  3. 반도체 디바이스(예: 다이오드ㆍ트랜지스터ㆍ반도체 기반 트랜스듀서), 감광성 반도체 디바이스(광전지는 모듈에 조립되었거나 패널로 구성되었는지 여부와 관계없이 포함한다), 발광다이오드[(엘이디), 다른 발광다이오드와 결합되었는지 여부과 관계없이 포함한다], 장착된 압전기 결정소자
#  4. 엑스선이나 알파선ㆍ베타선ㆍ감마선ㆍ그 밖의 전리선을 사용하는 기기(내과용ㆍ외과용ㆍ치과용ㆍ수의과용인지에 상관없으며 방사선 사진용이나 방사선 치료용 기기ㆍ엑스선관과 그 밖의 엑스선 발생기ㆍ고압 발생기ㆍ조절반ㆍ스크린ㆍ검사용이나 치료용 테이블ㆍ의자와 이와 유사한 물품을 포함한다)
#  5. 옥수수
#  6. 전자공업에 사용하기 위하여 도프처리된(doped) 화학원소(디스크ㆍ웨이퍼 모양이나 이와 유사한 모양으로 한정한다), 전자공업에 사용하기 위하여 도프처리된(doped) 화학화합물
#  7. 전동기와 발전기(발전세트는 제외한다)
#  8. 전화기(셀룰러 통신망용이나 그 밖의 무선통신망용의 스마트폰과 그 밖의 전화기를 포함한다)와 음성ㆍ영상이나 그 밖의 자료의 송신용ㆍ수신용 그 밖의 기기(근거리 통신망이나 원거리 통신망과 같은 유선ㆍ무선 통신망에서 통신하기 위한 기기를 포함하며, 제8443호ㆍ제8525호ㆍ제8527호ㆍ제8528호의 송신용ㆍ수신용 기기는 제외한다)
#  9. 불꽃점화식이나 압축점화식 내연기관의 점화용ㆍ시동용 전기기기(예: 점화용 자석발전기ㆍ자석발전기ㆍ점화코일ㆍ점화플러그ㆍ예열플러그ㆍ시동전동기), 내연기관에 부속되는 발전기(예: 직류발전기ㆍ교류발전기)와 개폐기
# 10. 그 밖의 차량(추진용 전동기만을 갖춘 것)
# 11. 석유가스와 그 밖의 가스 상태의 탄화수소
# 12. 천연고무ㆍ발라타(balata)ㆍ구타페르카(gutta-percha)ㆍ구아율(guayule)ㆍ치클(chicle)과 이와 유사한 천연 검(gum)[일차제품(primary form)ㆍ판ㆍ시트(sheet)ㆍ스트립 모양으로 한정한다]
#
# 🔸 클러스터 7 체인 순서 (총 14개)
#  1. 전기식의 즉시식ㆍ저장식 물가열기와 투입식 가열기, 난방기기와 토양가열기, 전기가열식 이용기기[예: 헤어드라이어ㆍ헤어컬러(hair curler)ㆍ컬링통히터(curling tong heater)], 손 건조기, 전기다리미, 그 밖의 가정용 전열기기, 전열용 저항체(제8545호의 것은 제외한다)
#  2. 합성필라멘트사의 직물(제5404호 재료로 직조한 직물을 포함한다)
#  3. 정형외과용 기기(목발ㆍ외과용 벨트와 탈장대를 포함한다), 골절 치료용 부목과 그 밖의 골절 치료구, 인공 인체 부분, 보청기, 결함ㆍ장애를 보정하기 위하여 착용하거나 휴대하거나 인체에 삽입하는 그 밖의 기기
#  4. 원목[껍질ㆍ변재(邊材)를 벗긴 것인지 또는 거칠게 각을 뜬 것인지에 상관없다]
#  5. 실린더용량이 3,000시시를 초과하는 것
#  6. 휴대용 전등(건전지ㆍ축전지ㆍ자석발전기와 같은 자체 전원기능을 갖춘 것으로 한정하며, 제8512호의 조명기구는 제외한다)
#  7. 백금(가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)
#  8. 그 밖의 차량[압축점화식 피스톤 내연기관(디젤이나 세미디젤)과 추진용 모터로서의 전동기를 둘 다 갖춘 것으로서, 외부 전원에 플러그를 꽂아 충전할 수 있는 방식의 것은 제외한다]
#  9. 안티모니와 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
# 10. 발전세트와 회전변환기
# 11. 철강으로 만든 구조물(제9406호의 조립식 건축물은 제외한다)과 구조물의 부분품[예: 다리와 교량ㆍ수문ㆍ탑ㆍ격자주(格子柱)ㆍ지붕ㆍ지붕틀ㆍ문과 창 및 이들의 틀과 문지방ㆍ셔터ㆍ난간ㆍ기둥], 구조물용으로 가공한 철강으로 만든 판ㆍ대ㆍ봉ㆍ형재(形材)ㆍ관(管)과 이와 유사한 것
# 12. 자주식(自走式) 철도용이나 궤도용 객차와 화차(제8604호의 것은 제외한다)
# 13. 인조필라멘트사(재봉사는 제외하며, 소매용으로 한정한다)
# 14. 대두유와 그 분획물(정제했는지에 상관없으며 화학적으로 변성 가공한 것은 제외한다)
#
# 🔸 클러스터 8 체인 순서 (총 8개)
#  1. 도포하지 않은 크라프트지와 판지[롤 모양이나 시트(sheet) 모양으로 한정하며, 제4802호나 제4803호의 것은 제외한다]
#  2. 철도용이나 궤도용 기관차나 차량의 부분품
#  3. 대두(부수었는지에 상관없다)
#  4. 서멧(cermet)과 그 제품[웨이스트(waste)와 스크랩(scrap)을 포함한다]
#  5. 면도기ㆍ이발기ㆍ모발제거기[전동기를 갖춘 것으로 한정한다]
#  6. 전기기계식의 가정용 기기(전동기를 갖춘 것으로 한정하며, 제8508호의 진공청소기는 제외한다)
#  7. 그 밖의 차량(불꽃점화식 피스톤 내연기관과 추진용 모터로서의 전동기를 둘 다 갖춘 것으로서, 외부 전원에 플러그를 꽂아 충전할 수 있는 방식의 것으로 한정한다)
#  8. 금(백금을 도금한 금을 포함하며, 가공하지 않은 것ㆍ반가공한 모양이나 가루 모양인 것으로 한정한다)

# %%
plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_pca2[:, 0], X_pca2[:, 1], c=labels2, cmap='tab20', s=50)
plt.title("PCA of Clustered Data", fontsize=16)
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
plt.colorbar(scatter, label='Cluster ID')
plt.grid(True)
plt.show()
